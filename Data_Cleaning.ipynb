# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import requests
import json
import time
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Data/aac_intakes_outcomes.csv')

# %%
df.outcome_type.unique()
# Out:
# array(['Return to Owner', 'Transfer', 'Adoption', 'Euthanasia', 'Died',
#        'Rto-Adopt', 'Missing', 'Disposal', nan, 'Relocate'], dtype=object)

# %%
df.columns
# Out:
# Index(['age_upon_outcome', 'animal_id_outcome', 'date_of_birth', 'outcome_subtype', 'outcome_type', 'sex_upon_outcome', 'age_upon_outcome_(days)', 'age_upon_outcome_(years)', 'age_upon_outcome_age_group', 'outcome_datetime', 'outcome_month', 'outcome_year', 'outcome_monthyear', 'outcome_weekday', 'outcome_hour', 'outcome_number', 'dob_year', 'dob_month', 'dob_monthyear', 'age_upon_intake', 'animal_id_intake', 'animal_type', 'breed', 'color', 'found_location', 'intake_condition', 'intake_type', 'sex_upon_intake', 'count', 'age_upon_intake_(days)', 'age_upon_intake_(years)', 'age_upon_intake_age_group', 'intake_datetime', 'intake_month', 'intake_year', 'intake_monthyear', 'intake_weekday', 'intake_hour', 'intake_number', 'time_in_shelter', 'time_in_shelter_days'], dtype='object')

# %%
df.outcome_type.value_counts(dropna=False)
# Out:
# Adoption           33594
# Transfer           23799
# Return to Owner    14791
# Euthanasia          6244
# Died                 690
# Disposal             304
# Rto-Adopt            179
# Missing               46
# Relocate              15
# NaN                   10
# Name: outcome_type, dtype: int64

# %%
df[df.outcome_type=='Transfer'].head()
# Out:
#    age_upon_outcome animal_id_outcome        date_of_birth outcome_subtype outcome_type sex_upon_outcome  age_upon_outcome_(days)  age_upon_outcome_(years) age_upon_outcome_age_group     outcome_datetime  outcome_month  outcome_year outcome_monthyear outcome_weekday  outcome_hour  outcome_number  dob_year  dob_month dob_monthyear age_upon_intake animal_id_intake animal_type                   breed              color                      found_location intake_condition      intake_type sex_upon_intake  count  age_upon_intake_(days)  age_upon_intake_(years) age_upon_intake_age_group      intake_datetime  intake_month  intake_year intake_monthyear intake_weekday  intake_hour  intake_number             time_in_shelter  time_in_shelter_days
# 3          10 years           A047759  2004-04-02 00:00:00         Partner     Transfer    Neutered Male                     3650                      10.0                (7.5, 10.0]  2014-04-07 15:12:00              4          2014           2014-04          Monday            15             1.0      2004          4       2014-04        10 years          A047759         Dog               Dachshund           Tricolor                         Austin (TX)           Normal  Owner Surrender   Neutered Male      1                    3650                     10.0               (7.5, 10.0]  2014-04-02 15:55:00             4         2014          2014-04      Wednesday           15            1.0   4 days 23:17:00.000000000              4.970139
# 11         14 years           A197810  2000-01-21 00:00:00         Partner     Transfer    Spayed Female                     5110                      14.0               (12.5, 15.0]  2014-12-22 15:23:00             12          2014           2014-12          Monday            15             1.0      2000          1       2014-12        14 years          A197810         Cat  American Shorthair Mix  Brown Tabby/White  4616 E Cesar Chavez in Austin (TX)           Normal            Stray   Spayed Female      1                    5110                     14.0              (12.5, 15.0]  2014-12-08 12:30:00            12         2014          2014-12         Monday           12            1.0  14 days 02:53:00.000000000             14.120139
# 28         15 years           A238870  2001-05-24 00:00:00         Partner     Transfer    Neutered Male                     5475                      15.0               (12.5, 15.0]  2016-06-17 12:37:00              6          2016           2016-06          Friday            12             1.0      2001          5       2016-06        15 years          A238870         Dog         Rat Terrier Mix         Gray/White   8411 Ganttcrest Dr in Austin (TX)           Normal            Stray   Neutered Male      1                    5475                     15.0              (12.5, 15.0]  2016-06-09 16:22:00             6         2016          2016-06       Thursday           16            1.0   7 days 20:15:00.000000000              7.843750
# 30         15 years           A245945  2000-05-23 00:00:00         Partner     Transfer    Neutered Male                     5475                      15.0               (12.5, 15.0]  2015-05-25 11:49:00              5          2015           2015-05          Monday            11             1.0      2000          5       2015-05        15 years          A245945         Dog  Labrador Retriever Mix                Tan    7403 Blessing Ave in Austin (TX)           Normal            Stray   Neutered Male      1                    5475                     15.0              (12.5, 15.0]  2015-05-20 22:34:00             5         2015          2015-05      Wednesday           22            1.0   4 days 13:15:00.000000000              4.552083
# 41         14 years           A260631  2000-04-20 00:00:00         Partner     Transfer    Neutered Male                     5110                      14.0               (12.5, 15.0]  2014-10-20 13:50:00             10          2014           2014-10          Monday            13             1.0      2000          4       2014-10        14 years          A260631         Cat   Domestic Longhair Mix        Black/White    600 Barwood Place in Austin (TX)           Normal            Stray   Neutered Male      1                    5110                     14.0              (12.5, 15.0]  2014-10-16 18:17:00            10         2014          2014-10       Thursday           18            1.0   3 days 19:33:00.000000000              3.814583

# %%
len(set([1,1,1,1,1]))
# Out:
# 1

# %%
df.rename(columns={'age_upon_intake_(days)': 'age_upon_intake_days', 'age_upon_intake_(years)': 'age_upon_intake_tears'}, inplace=True)

# %%
print(len(df),len(set(df.animal_id_intake)), len(set(df.animal_id_outcome)))
# Out:
# 79672 71961 71961

# %%
plt.scatter(df[df.outcome_type=='Adoption'].age_upon_intake_days, df[df.outcome_type=='Adoption'].time_in_shelter_days)

# %%
df[df.outcome_type=='Adoption'].time_in_shelter_days.describe()
# Out:
# count    33594.000000
# mean        29.460366
# std         52.144263
# min          0.000694
# 25%          4.961806
# 50%         10.225000
# 75%         36.210417
# max       1268.975000
# Name: time_in_shelter_days, dtype: float64

# %%
plt.boxplot(df[df.outcome_type=='Adoption'].time_in_shelter_days)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9637810d50>,
#   <matplotlib.lines.Line2D at 0x7f963764de50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f963781c850>,
#   <matplotlib.lines.Line2D at 0x7f963781cd50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9637810110>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9637810e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f96378237d0>],
#  'means': []}

# %%
df.color.value_counts()
# Out:
# Black/White                    8270
# Black                          6673
# Brown Tabby                    4471
# Brown                          3598
# White                          2835
#                                ...
# Cream Tabby/Orange Tabby          1
# White/Tortie                      1
# Red Tick/Blue Tick                1
# Black/Gold                        1
# Brown Brindle/Brown Brindle       1
# Name: color, Length: 529, dtype: int64

# %%
df.loc[0, 'color'].split('/')
# Out:
# ['Yellow', 'White']

# %%
#color split loop. 
animal_dict={}

for animal in df.index:
    color_dict={}
    color_list= df.loc[animal, 'color'].split('/')
    color_dict['color1']=color_list[0]
    color_dict['has_second_color']=len(color_list)-1
    if color_dict['has_second_color']:
        color_dict['color2']=color_list[-1]
    animal_dict[animal]=color_dict
len(animal_dict)==len(df)
# Out:
# True

# %%
to_join = pd.DataFrame.from_dict(animal_dict, orient='index')

# %%
df = df.join(to_join, how='left')

# %%
df = df[df.outcome_type=='Adoption']

# %%
df.head()
# Out:
#    age_upon_outcome animal_id_outcome        date_of_birth outcome_subtype outcome_type sex_upon_outcome  age_upon_outcome_(days)  age_upon_outcome_(years) age_upon_outcome_age_group     outcome_datetime  outcome_month  outcome_year outcome_monthyear outcome_weekday  outcome_hour  outcome_number  dob_year  dob_month dob_monthyear age_upon_intake animal_id_intake animal_type                      breed        color                            found_location intake_condition      intake_type sex_upon_intake  count  age_upon_intake_days  age_upon_intake_tears age_upon_intake_age_group      intake_datetime  intake_month  intake_year intake_monthyear intake_weekday  intake_hour  intake_number             time_in_shelter  time_in_shelter_days    color1  has_second_color color2
# 12         16 years           A200922  1997-10-03 00:00:00          Foster     Adoption    Neutered Male                     5840                      16.0               (15.0, 17.5]  2013-11-22 09:44:00             11          2013           2013-11          Friday             9             1.0      1997         10       2013-11        16 years          A200922         Dog              Dachshund Mix    Black/Tan                               Austin (TX)           Normal  Owner Surrender   Neutered Male      1                  5840                   16.0              (15.0, 17.5]  2013-10-03 15:47:00            10         2013          2013-10       Thursday           15            1.0  49 days 17:57:00.000000000             49.747917     Black                 1    Tan
# 14         17 years           A210457  1999-06-01 00:00:00          Foster     Adoption    Neutered Male                     6205                      17.0               (15.0, 17.5]  2016-10-07 12:34:00             10          2016           2016-10          Friday            12             1.0      1999          6       2016-10        17 years          A210457         Dog        Chihuahua Shorthair    Tan/Black          4424 S Mopac #412 in Austin (TX)             Aged    Public Assist   Neutered Male      1                  6205                   17.0              (15.0, 17.5]  2016-09-28 12:05:00             9         2016          2016-09      Wednesday           12            1.0   9 days 00:29:00.000000000              9.020139       Tan                 1  Black
# 22         15 years           A226069  2000-06-17 00:00:00          Foster     Adoption    Neutered Male                     5475                      15.0               (12.5, 15.0]  2015-10-29 15:00:00             10          2015           2015-10        Thursday            15             1.0      2000          6       2015-10        15 years          A226069         Dog  Labrador Retriever/Beagle  Sable/White  Wheless Ln And Berkman Dr in Austin (TX)           Normal            Stray   Neutered Male      1                  5475                   15.0              (12.5, 15.0]  2015-10-06 12:29:00            10         2015          2015-10        Tuesday           12            1.0  23 days 02:31:00.000000000             23.104861     Sable                 1  White
# 32         15 years           A249087  2001-01-02 00:00:00          Foster     Adoption    Spayed Female                     5475                      15.0               (12.5, 15.0]  2016-11-15 10:37:00             11          2016           2016-11         Tuesday            10             1.0      2001          1       2016-11        15 years          A249087         Dog        German Shepherd Mix  Black/Brown    E 6Th St And Pedernales in Austin (TX)           Normal            Stray   Spayed Female      1                  5475                   15.0              (12.5, 15.0]  2016-08-17 14:05:00             8         2016          2016-08      Wednesday           14            1.0  89 days 20:32:00.000000000             89.855556     Black                 1  Brown
# 48         11 years           A274546  2002-05-25 00:00:00             NaN     Adoption    Spayed Female                     4015                      11.0               (10.0, 12.5]  2013-11-16 12:24:00             11          2013           2013-11        Saturday            12             1.0      2002          5       2013-11        11 years          A274546         Dog                Pointer Mix     Tricolor     Manchaca And Slaughter in Austin (TX)           Normal            Stray   Spayed Female      1                  4015                   11.0              (10.0, 12.5]  2013-11-13 18:16:00            11         2013          2013-11      Wednesday           18            1.0   2 days 18:08:00.000000000              2.755556  Tricolor                 0    NaN

# %%
df.sex_upon_outcome.value_counts()
# Out:
# Neutered Male    16188
# Spayed Female    15925
# Intact Female      762
# Intact Male        650
# Unknown             69
# Name: sex_upon_outcome, dtype: int64

# %%
df.sex_upon_intake.value_counts()
# Out:
# Intact Male      12406
# Intact Female    12133
# Spayed Female     4554
# Neutered Male     4432
# Unknown             69
# Name: sex_upon_intake, dtype: int64

# %%
df.animal_type.value_counts()
# Out:
# Dog      20581
# Cat      12675
# Other      223
# Bird       115
# Name: animal_type, dtype: int64

# %%
df=df[(df.animal_type=='Dog')|(df.animal_type=='Cat')]

# %%
df['is_dog']=np.where(df.animal_type=='Dog', 1, 0)

# %%
df[(df.sex_upon_outcome=='Intact Male')|(df.sex_upon_outcome=='Intact Female')].time_in_shelter_days.plot(kind='hist')

# %%
df.color1.unique()
# Out:
# array(['Black', 'Tan', 'Sable', 'Tricolor', 'Black Smoke', 'Brown',
#        'Brown Tabby', 'Orange Tabby', 'Lilac Point', 'Tortie', 'Blue',
#        'Red', 'White', 'Flame Point', 'Calico', 'Blue Tick', 'Chocolate',
#        'Seal Point', 'Black Tabby', 'Brown Brindle', 'Black Brindle',
#        'Blue Cream', 'Cream', 'Buff', 'Gold', 'Blue Tabby', 'Torbie',
#        'Calico Point', 'Gray', 'Blue Merle', 'Lynx Point', 'Tortie Point',
#        'Fawn', 'Black Tiger', 'Red Tick', 'Yellow', 'Brown Merle',
#        'Blue Tiger', 'Yellow Brindle', 'Apricot', 'Blue Point',
#        'Cream Tabby', 'Silver', 'Red Merle', 'Gray Tabby', 'Brown Tiger',
#        'Chocolate Point', 'Silver Tabby', 'Liver', 'Ruddy', 'Agouti',
#        'Orange', 'Liver Tick', 'Blue Smoke', 'Silver Lynx Point'],
#       dtype=object)

# %%
df.sex_upon_outcome.value_counts()
# Out:
# Neutered Male    16105
# Spayed Female    15848
# Intact Female      724
# Intact Male        578
# Unknown              1
# Name: sex_upon_outcome, dtype: int64

# %%
df.drop(df[df.sex_upon_outcome=='Unknown'].index,axis= 0, inplace=True)

# %%
df.sex_upon_outcome.value_counts()
# Out:
# Neutered Male    16105
# Spayed Female    15848
# Intact Female      724
# Intact Male        578
# Name: sex_upon_outcome, dtype: int64

# %%
animal_dict={}
for animal in df.index:
    gender_dict={}
    gender_list= df.loc[animal, 'sex_upon_outcome'].split()
    gender_dict['is_male']= int(gender_list[-1]=='Male')
    gender_dict['is_fixed']= int(gender_list[0]!='Intact')
    animal_dict[animal]=gender_dict
if len(animal_dict)==len(df):
    df = df.join(pd.DataFrame.from_dict(animal_dict, orient='index'), how='left')
df.columns
# Out:
# Index(['age_upon_outcome', 'animal_id_outcome', 'date_of_birth', 'outcome_subtype', 'outcome_type', 'sex_upon_outcome', 'age_upon_outcome_(days)', 'age_upon_outcome_(years)', 'age_upon_outcome_age_group', 'outcome_datetime', 'outcome_month', 'outcome_year', 'outcome_monthyear', 'outcome_weekday', 'outcome_hour', 'outcome_number', 'dob_year', 'dob_month', 'dob_monthyear', 'age_upon_intake', 'animal_id_intake', 'animal_type', 'breed', 'color', 'found_location', 'intake_condition', 'intake_type', 'sex_upon_intake', 'count', 'age_upon_intake_days', 'age_upon_intake_tears', 'age_upon_intake_age_group', 'intake_datetime', 'intake_month', 'intake_year', 'intake_monthyear', 'intake_weekday', 'intake_hour', 'intake_number', 'time_in_shelter', 'time_in_shelter_days', 'color1', 'has_second_color', 'color2', 'is_dog', 'is_male', 'is_fixed'], dtype='object')

# %%
df.intake_condition.value_counts()
# Out:
# Normal      31188
# Injured       957
# Sick          486
# Nursing       484
# Aged           65
# Other          37
# Pregnant       21
# Feral          17
# Name: intake_condition, dtype: int64

# %%
df.head()
# Out:
#    age_upon_outcome animal_id_outcome        date_of_birth outcome_subtype outcome_type sex_upon_outcome  age_upon_outcome_(days)  age_upon_outcome_(years) age_upon_outcome_age_group     outcome_datetime  outcome_month  outcome_year outcome_monthyear outcome_weekday  outcome_hour  outcome_number  dob_year  dob_month dob_monthyear age_upon_intake animal_id_intake animal_type                      breed        color                            found_location intake_condition      intake_type sex_upon_intake  count  age_upon_intake_days  age_upon_intake_tears age_upon_intake_age_group      intake_datetime  intake_month  intake_year intake_monthyear intake_weekday  intake_hour  intake_number             time_in_shelter  time_in_shelter_days    color1  has_second_color color2  is_dog  is_male  is_fixed
# 12         16 years           A200922  1997-10-03 00:00:00          Foster     Adoption    Neutered Male                     5840                      16.0               (15.0, 17.5]  2013-11-22 09:44:00             11          2013           2013-11          Friday             9             1.0      1997         10       2013-11        16 years          A200922         Dog              Dachshund Mix    Black/Tan                               Austin (TX)           Normal  Owner Surrender   Neutered Male      1                  5840                   16.0              (15.0, 17.5]  2013-10-03 15:47:00            10         2013          2013-10       Thursday           15            1.0  49 days 17:57:00.000000000             49.747917     Black                 1    Tan       1        1         1
# 14         17 years           A210457  1999-06-01 00:00:00          Foster     Adoption    Neutered Male                     6205                      17.0               (15.0, 17.5]  2016-10-07 12:34:00             10          2016           2016-10          Friday            12             1.0      1999          6       2016-10        17 years          A210457         Dog        Chihuahua Shorthair    Tan/Black          4424 S Mopac #412 in Austin (TX)             Aged    Public Assist   Neutered Male      1                  6205                   17.0              (15.0, 17.5]  2016-09-28 12:05:00             9         2016          2016-09      Wednesday           12            1.0   9 days 00:29:00.000000000              9.020139       Tan                 1  Black       1        1         1
# 22         15 years           A226069  2000-06-17 00:00:00          Foster     Adoption    Neutered Male                     5475                      15.0               (12.5, 15.0]  2015-10-29 15:00:00             10          2015           2015-10        Thursday            15             1.0      2000          6       2015-10        15 years          A226069         Dog  Labrador Retriever/Beagle  Sable/White  Wheless Ln And Berkman Dr in Austin (TX)           Normal            Stray   Neutered Male      1                  5475                   15.0              (12.5, 15.0]  2015-10-06 12:29:00            10         2015          2015-10        Tuesday           12            1.0  23 days 02:31:00.000000000             23.104861     Sable                 1  White       1        1         1
# 32         15 years           A249087  2001-01-02 00:00:00          Foster     Adoption    Spayed Female                     5475                      15.0               (12.5, 15.0]  2016-11-15 10:37:00             11          2016           2016-11         Tuesday            10             1.0      2001          1       2016-11        15 years          A249087         Dog        German Shepherd Mix  Black/Brown    E 6Th St And Pedernales in Austin (TX)           Normal            Stray   Spayed Female      1                  5475                   15.0              (12.5, 15.0]  2016-08-17 14:05:00             8         2016          2016-08      Wednesday           14            1.0  89 days 20:32:00.000000000             89.855556     Black                 1  Brown       1        0         1
# 48         11 years           A274546  2002-05-25 00:00:00             NaN     Adoption    Spayed Female                     4015                      11.0               (10.0, 12.5]  2013-11-16 12:24:00             11          2013           2013-11        Saturday            12             1.0      2002          5       2013-11        11 years          A274546         Dog                Pointer Mix     Tricolor     Manchaca And Slaughter in Austin (TX)           Normal            Stray   Spayed Female      1                  4015                   11.0              (10.0, 12.5]  2013-11-13 18:16:00            11         2013          2013-11      Wednesday           18            1.0   2 days 18:08:00.000000000              2.755556  Tricolor                 0    NaN       1        0         1

# %%
city_dict= {}
for animal in df.index:
    string=df.loc[animal, 'found_location']
    if len(string.split())>3:
        location_list = string.split(' in ')[-1]
        city_dict[animal]=' '.join(location_list.split()[:-1])
    else:
        city_dict[animal]=' '.join(string.split()[:-1])
if len(city_dict)==len(df):
    to_join=pd.DataFrame.from_dict(city_dict, orient='index')
to_join.head()
# Out:
#          0
# 12  Austin
# 14  Austin
# 22  Austin
# 32  Austin
# 48  Austin

# %%
to_join.rename(columns={0:'found_city'}, inplace=True)

# %%
df= df.join(to_join, how='left')

# %%
for name in df.found_city.unique():
    print(name)
# Out:
# Austin
# Travis
# Pflugerville
# Manor
# Lago Vista
# Outside
# Del Valle
# Lakeway
# Williamson
# Hays
# Round Rock
# Webberville
# Bastrop
# Cedar Park
# Jonestown
# Burnet
# Leander
# Creedmoor
# West Lake Hills
# Bee Cave
# Mustang Ridge
# Sunset Valley
# Point Venture
# Caldwell
# Blanco

# %%
df.animal_id_intake.nunique()
# Out:
# 30365

# %% [markdown]
# Leveraging Found City to Create Found Regions

# %%
test={}
for name in df.found_city.unique():
    if name != 'Outside':
        try:
            time.sleep(1)
            query= "+".join(name.split())+"+TX"
            response = requests.get('https://nominatim.openstreetmap.org/search?q='+query+'&format=jsonv2')
            payload = response.json()
            test[name]={'lat':payload[0]['lat'],'lon':payload[0]['lon']}
        except IndexError:
            test[name]={'lat':None, 'lon':None}
print(test)
# Out:
# {'Austin': {'lat': '30.2711286', 'lon': '-97.7436995'}, 'Travis': {'lat': '30.2878569', 'lon': '-97.7561392'}, 'Pflugerville': {'lat': '30.4393696', 'lon': '-97.6200043'}, 'Manor': {'lat': '30.3407629', 'lon': '-97.5569456'}, 'Lago Vista': {'lat': '30.4601975', 'lon': '-97.9883477'}, 'Del Valle': {'lat': '23.2699265', 'lon': '-106.3894398'}, 'Lakeway': {'lat': '30.3644888', 'lon': '-97.9875325'}, 'Williamson': {'lat': '30.6580927', 'lon': '-97.6041649'}, 'Hays': {'lat': '30.0447901', 'lon': '-98.0393127'}, 'Round Rock': {'lat': '30.508235', 'lon': '-97.6788934'}, 'Webberville': {'lat': '30.231045', 'lon': '-97.5166653'}, 'Bastrop': {'lat': '30.0900753', 'lon': '-97.3127179'}, 'Cedar Park': {'lat': '30.5217116', 'lon': '-97.827833'}, 'Jonestown': {'lat': '30.4954748', 'lon': '-97.9233468'}, 'Burnet': {'lat': '30.7763939', 'lon': '-98.1700016'}, 'Leander': {'lat': '30.5586046', 'lon': '-97.8444364'}, 'Creedmoor': {'lat': '30.0899368', 'lon': '-97.7338917'}, 'West Lake Hills': {'lat': '30.2877039', 'lon': '-97.8068157'}, 'Bee Cave': {'lat': '30.3085373', 'lon': '-97.94501'}, 'Mustang Ridge': {'lat': '30.0568828', 'lon': '-97.6911124'}, 'Sunset Valley': {'lat': '30.22651975', 'lon': '-97.81494760118338'}, 'Point Venture': {'lat': '30.3831401', 'lon': '-97.9988151849835'}, 'Caldwell': {'lat': '29.8298971', 'lon': '-97.5959641'}, 'Blanco': {'lat': '30.2419274', 'lon': '-98.4004594'}}

# %%
for location in test:
    test[location]['found_count'] = df.found_city.value_counts()[location]
    if location in df[df.animal_type=='Cat'].found_city.value_counts().index:
        test[location]['found_cats']= df[df.animal_type=='Cat'].found_city.value_counts()[location] 
    else: 
        test[location]['found_cats']= 0
    if location in df[df.animal_type=='Dog'].found_city.value_counts().index:    
        test[location]['found_dogs']= df[df.animal_type=='Dog'].found_city.value_counts()[location] 
    else:
        test[location]['found_dogs']= 0

# %%
df[df.animal_type=='Cat'].found_city.value_counts().index
# Out:
# Index(['Austin', 'Travis', 'Del Valle', 'Manor', 'Pflugerville', 'Outside', 'Leander', 'Lago Vista', 'Bastrop', 'Round Rock', 'Lakeway', 'Creedmoor', 'Cedar Park', 'Jonestown', 'Hays', 'Bee Cave', 'Williamson', 'Mustang Ridge', 'Webberville', 'Sunset Valley', 'Burnet', 'West Lake Hills'], dtype='object')

# %%
df['found_lat'] =df.found_city.map(lambda x: float(test[x]['lat']) if x != 'Outside' else None)
df['found_lon'] =df.found_city.map(lambda x: float(test[x]['lon']) if x != 'Outside' else None)

# %%
import plotly.express as px

# %%
city_df= pd.DataFrame.from_dict(test, orient='index')

# %%
city_df = city_df.applymap(lambda x: float(x))

# %%
fig = px.scatter_mapbox(city_df, lat= "lat", lon="lon", hover_name=city_df.index, hover_data=['found_count','found_cats', 'found_dogs'])
fig.update_layout(mapbox_style="open-street-map")

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fd88e4e20f9b> in <module>
# ----> 1 fig = px.scatter_mapbox(city_df, lat= "lat", lon="lon", hover_name=city_df.index, hover_data=['found_count','found_cats', 'found_dogs'])
#       2 fig.update_layout(mapbox_style="open-street-map")
#       3
#       4 fig.show()
#
# NameError: name 'px' is not defined

# %%
region_bins= {'Austin':['Austin'], 
       'Travis':['Travis', 'West Lake Hills', 'Sunset Valley'], 
       'South': ['Del Valle', 'Creedmoor', 'Mustang Ridge', 'Caldwell', 'Hays'],
       'Outside': ['Outside', 'Blanco'],
        'Northwest':['Burnet', 'Bee Cave', 'Lakeway', 'Point Venture', 'Lago Vista', 'Jonestown'],
        'North': ['Cedar Park', 'Leander', 'Round Rock', 'Pflugerville', 'Williamson'],
        'East': ['Manor', 'Webberville', 'Bastrop']
             }
regions={}
for a, b in region_bins.items():
    for city in b:
        regions[city]= a
df['region']= df.found_city.map(regions)

# %%
df.region.value_counts(dropna=False)
# Out:
# Austin       27516
# Travis        2636
# South          947
# East           766
# North          733
# Outside        482
# Northwest      175
# Name: region, dtype: int64

# %%
df['found_city'].value_counts()
# Out:
# Austin             27516
# Travis              2624
# Del Valle            833
# Manor                720
# Pflugerville         494
# Outside              481
# Leander              105
# Lago Vista            78
# Round Rock            54
# Cedar Park            51
# Hays                  45
# Lakeway               45
# Creedmoor             43
# Bastrop               34
# Jonestown             29
# Williamson            29
# Mustang Ridge         21
# Bee Cave              18
# Webberville           12
# West Lake Hills        8
# Caldwell               5
# Sunset Valley          4
# Burnet                 3
# Point Venture          2
# Blanco                 1
# Name: found_city, dtype: int64

# %%
df.reset_index(inplace=True)

# %%
df.breed.unique()
# Out:
# array(['Dachshund Mix', 'Chihuahua Shorthair',
#        'Labrador Retriever/Beagle', ..., 'Chihuahua Shorthair/Catahoula',
#        'Yorkshire Terrier/Dachshund', 'Norfolk Terrier/Pug'], dtype=object)

# %%
df= df[['index', 'age_upon_outcome', 'animal_id_outcome', 'date_of_birth', 'outcome_subtype', 'outcome_type', 'sex_upon_outcome', 'age_upon_outcome_(days)', 'age_upon_outcome_(years)', 'age_upon_outcome_age_group', 'outcome_datetime', 'outcome_month', 'outcome_year', 'outcome_monthyear', 'outcome_weekday', 'outcome_hour', 'outcome_number', 'dob_year', 'dob_month', 'dob_monthyear', 'age_upon_intake', 'animal_id_intake', 'animal_type', 'breed', 'color', 'found_location', 'intake_condition', 'intake_type', 'sex_upon_intake', 'count', 'age_upon_intake_days', 'age_upon_intake_tears', 'age_upon_intake_age_group', 'intake_datetime', 'intake_month', 'intake_year', 'intake_monthyear', 'intake_weekday', 'intake_hour', 'intake_number', 'time_in_shelter', 'time_in_shelter_days', 'color1', 'has_second_color', 'color2', 'is_dog', 'is_male', 'is_fixed', 'found_city', 'found_lat', 'found_lon', 'region']]

# %%
#breed split loop. 
animal_dict={}

for animal in df.index:
    breed_dict={}
    breed_list= df.loc[animal, 'breed'].split('/')
    breed_dict['breed1']=breed_list[0]
    breed_dict['is_breed2'] = 0
    if 'Mix' in breed_list[0].split():
        breed_dict['is_mix']= 1
    elif len(breed_list) >1:
        breed_dict['is_mix'] = 1
        breed_dict['breed2'] = breed_list[-1]
        breed_dict['is_breed2'] = 1
    else:
        breed_dict['is_mix']=0
    animal_dict[animal] = breed_dict
if len(animal_dict)==len(df):
    df = df.join(pd.DataFrame.from_dict(animal_dict, orient='index'), how='left')

# %%
set(list(df.breed1.unique())+list(df.breed2.unique()))
# Out:
# {'Abyssinian',
#  'Abyssinian Mix',
#  'Affenpinscher',
#  'Affenpinscher Mix',
#  'Afghan Hound',
#  'Airedale Terrier',
#  'Airedale Terrier Mix',
#  'Akbash Mix',
#  'Akita',
#  'Akita Mix',
#  'Alaskan Husky',
#  'Alaskan Husky Mix',
#  'Alaskan Malamute',
#  'Alaskan Malamute Mix',
#  'American Bulldog',
#  'American Bulldog Mix',
#  'American Curl Shorthair',
#  'American Curl Shorthair Mix',
#  'American Eskimo',
#  'American Eskimo Mix',
#  'American Foxhound',
#  'American Foxhound Mix',
#  'American Pit Bull Terrier',
#  'American Pit Bull Terrier Mix',
#  'American Shorthair Mix',
#  'American Staffordshire Terrier',
#  'American Staffordshire Terrier Mix',
#  'American Wirehair Mix',
#  'Anatol Shepherd',
#  'Anatol Shepherd Mix',
#  'Angora Mix',
#  'Australian Cattle Dog',
#  'Australian Cattle Dog Mix',
#  'Australian Kelpie',
#  'Australian Kelpie Mix',
#  'Australian Shepherd',
#  'Australian Shepherd Mix',
#  'Australian Terrier',
#  'Australian Terrier Mix',
#  'Balinese Mix',
#  'Basenji',
#  'Basenji Mix',
#  'Basset Hound',
#  'Basset Hound Mix',
#  'Beagle',
#  'Beagle Mix',
#  'Bearded Collie',
#  'Bearded Collie Mix',
#  'Beauceron',
#  'Beauceron Mix',
#  'Bedlington Terr Mix',
#  'Belgian Malinois',
#  'Belgian Malinois Mix',
#  'Belgian Sheepdog',
#  'Belgian Sheepdog Mix',
#  'Belgian Tervuren Mix',
#  'Bengal',
#  'Bengal Mix',
#  'Bernese Mountain Dog',
#  'Bernese Mountain Dog Mix',
#  'Bichon Frise',
#  'Bichon Frise Mix',
#  'Black',
#  'Black Mouth Cur',
#  'Black Mouth Cur Mix',
#  'Bloodhound',
#  'Bloodhound Mix',
#  'Blue Lacy',
#  'Blue Lacy Mix',
#  'Bluetick Hound',
#  'Bluetick Hound Mix',
#  'Boerboel Mix',
#  'Bombay Mix',
#  'Border Collie',
#  'Border Collie Mix',
#  'Border Terrier',
#  'Border Terrier Mix',
#  'Borzoi',
#  'Boston Terrier',
#  'Boston Terrier Mix',
#  'Boxer',
#  'Boxer Mix',
#  'Boykin Span',
#  'Boykin Span Mix',
#  'British Shorthair',
#  'British Shorthair Mix',
#  'Brittany',
#  'Brittany Mix',
#  'Bruss Griffon',
#  'Bruss Griffon Mix',
#  'Bull Terrier',
#  'Bull Terrier Miniature Mix',
#  'Bull Terrier Mix',
#  'Bulldog',
#  'Bulldog Mix',
#  'Bullmastiff',
#  'Bullmastiff Mix',
#  'Burmese',
#  'Cairn Terrier',
#  'Cairn Terrier Mix',
#  'Canaan Dog',
#  'Canaan Dog Mix',
#  'Cane Corso',
#  'Cane Corso Mix',
#  'Cardigan Welsh Corgi',
#  'Cardigan Welsh Corgi Mix',
#  'Carolina Dog',
#  'Carolina Dog Mix',
#  'Catahoula',
#  'Catahoula Mix',
#  'Cavalier Span',
#  'Cavalier Span Mix',
#  'Chartreux Mix',
#  'Chesa Bay Retr',
#  'Chesa Bay Retr Mix',
#  'Chihuahua Longhair',
#  'Chihuahua Longhair Mix',
#  'Chihuahua Shorthair',
#  'Chihuahua Shorthair Mix',
#  'Chinese Crested',
#  'Chinese Crested Mix',
#  'Chinese Sharpei',
#  'Chinese Sharpei Mix',
#  'Chow Chow',
#  'Chow Chow Mix',
#  'Cirneco',
#  'Cocker Spaniel',
#  'Cocker Spaniel Mix',
#  'Collie Rough',
#  'Collie Rough Mix',
#  'Collie Smooth',
#  'Collie Smooth Mix',
#  'Cornish Rex Mix',
#  'Coton De Tulear Mix',
#  'Cymric Mix',
#  'Dachshund',
#  'Dachshund Longhair',
#  'Dachshund Longhair Mix',
#  'Dachshund Mix',
#  'Dachshund Stan Mix',
#  'Dachshund Wirehair',
#  'Dachshund Wirehair Mix',
#  'Dalmatian',
#  'Dalmatian Mix',
#  'Dandie Dinmont Mix',
#  'Devon Rex Mix',
#  'Doberman Pinsch',
#  'Doberman Pinsch Mix',
#  'Dogo Argentino',
#  'Dogo Argentino Mix',
#  'Dogue De Bordeaux Mix',
#  'Domestic Longhair',
#  'Domestic Longhair Mix',
#  'Domestic Medium Hair',
#  'Domestic Medium Hair Mix',
#  'Domestic Shorthair',
#  'Domestic Shorthair Mix',
#  'Dutch Shepherd',
#  'Dutch Shepherd Mix',
#  'Eng Toy Spaniel Mix',
#  'English Bulldog',
#  'English Bulldog Mix',
#  'English Cocker Spaniel',
#  'English Cocker Spaniel Mix',
#  'English Coonhound',
#  'English Coonhound Mix',
#  'English Foxhound',
#  'English Foxhound Mix',
#  'English Pointer',
#  'English Pointer Mix',
#  'English Setter',
#  'English Shepherd Mix',
#  'English Springer Spaniel',
#  'English Springer Spaniel Mix',
#  'Feist',
#  'Feist Mix',
#  'Field Spaniel',
#  'Field Spaniel Mix',
#  'Finnish Spitz',
#  'Finnish Spitz Mix',
#  'Flat Coat Retriever',
#  'Flat Coat Retriever Mix',
#  'French Bulldog',
#  'French Bulldog Mix',
#  'German Pinscher',
#  'German Pinscher Mix',
#  'German Shepherd',
#  'German Shepherd Mix',
#  'German Shorthair Pointer',
#  'German Shorthair Pointer Mix',
#  'German Wirehaired Pointer',
#  'German Wirehaired Pointer Mix',
#  'Glen Of Imaal',
#  'Glen Of Imaal Mix',
#  'Golden Retriever',
#  'Golden Retriever Mix',
#  'Gordon Setter Mix',
#  'Grand Basset Griffon Vendeen Mix',
#  'Great Dane',
#  'Great Dane Mix',
#  'Great Pyrenees',
#  'Great Pyrenees Mix',
#  'Greater Swiss Mountain Dog Mix',
#  'Greyhound',
#  'Greyhound Mix',
#  'Harrier',
#  'Harrier Mix',
#  'Havana Brown Mix',
#  'Havanese',
#  'Havanese Mix',
#  'Himalayan',
#  'Himalayan Mix',
#  'Hovawart',
#  'Ibizan Hound',
#  'Ibizan Hound Mix',
#  'Irish Setter',
#  'Irish Terrier',
#  'Irish Terrier Mix',
#  'Irish Wolfhound',
#  'Irish Wolfhound Mix',
#  'Italian Greyhound',
#  'Italian Greyhound Mix',
#  'Jack Russell Terrier',
#  'Jack Russell Terrier Mix',
#  'Japanese Bobtail',
#  'Japanese Bobtail Mix',
#  'Javanese Mix',
#  'Jindo',
#  'Jindo Mix',
#  'Keeshond',
#  'Keeshond Mix',
#  'Kuvasz Mix',
#  'Labrador Retriever',
#  'Labrador Retriever Mix',
#  'Lakeland Terrier Mix',
#  'Landseer Mix',
#  'Leonberger',
#  'Leonberger Mix',
#  'Lhasa Apso',
#  'Lhasa Apso Mix',
#  'Lowchen',
#  'Lowchen Mix',
#  'Maine Coon',
#  'Maine Coon Mix',
#  'Maltese',
#  'Maltese Mix',
#  'Manchester Terrier',
#  'Manchester Terrier Mix',
#  'Manx',
#  'Manx Mix',
#  'Mastiff',
#  'Mastiff Mix',
#  'Mexican Hairless Mix',
#  'Miniature Pinscher',
#  'Miniature Pinscher Mix',
#  'Miniature Poodle',
#  'Miniature Poodle Mix',
#  'Miniature Schnauzer',
#  'Miniature Schnauzer Mix',
#  'Munchkin Shorthair Mix',
#  'Neapolitan Mastiff',
#  'Neapolitan Mastiff Mix',
#  'Newfoundland',
#  'Newfoundland Mix',
#  'Norfolk Terrier',
#  'Norfolk Terrier Mix',
#  'Norwegian Elkhound Mix',
#  'Norwegian Forest Cat Mix',
#  'Norwich Terrier',
#  'Norwich Terrier Mix',
#  'Nova Scotia Duck Tolling Retriever',
#  'Nova Scotia Duck Tolling Retriever Mix',
#  'Ocicat Mix',
#  'Old English Bulldog',
#  'Old English Bulldog Mix',
#  'Oriental Sh Mix',
#  'Otterhound',
#  'Otterhound Mix',
#  'Papillon',
#  'Papillon Mix',
#  'Parson Russell Terrier',
#  'Parson Russell Terrier Mix',
#  'Patterdale Terr',
#  'Patterdale Terr Mix',
#  'Pbgv',
#  'Pbgv Mix',
#  'Pekingese',
#  'Pekingese Mix',
#  'Pembroke Welsh Corgi',
#  'Pembroke Welsh Corgi Mix',
#  'Persian',
#  'Persian Mix',
#  'Pharaoh Hound',
#  'Pharaoh Hound Mix',
#  'Picardy Sheepdog',
#  'Picardy Sheepdog Mix',
#  'Pit Bull',
#  'Pit Bull Mix',
#  'Pixiebob Shorthair Mix',
#  'Plott Hound',
#  'Plott Hound Mix',
#  'Podengo Pequeno Mix',
#  'Pointer',
#  'Pointer Mix',
#  'Pomeranian',
#  'Pomeranian Mix',
#  'Port Water Dog Mix',
#  'Presa Canario',
#  'Presa Canario Mix',
#  'Pug',
#  'Pug Mix',
#  'Queensland Heeler',
#  'Queensland Heeler Mix',
#  'Ragdoll',
#  'Ragdoll Mix',
#  'Rat Terrier',
#  'Rat Terrier Mix',
#  'Redbone Hound',
#  'Redbone Hound Mix',
#  'Rhod Ridgeback',
#  'Rhod Ridgeback Mix',
#  'Rottweiler',
#  'Rottweiler Mix',
#  'Russian Blue',
#  'Russian Blue Mix',
#  'Saluki',
#  'Saluki Mix',
#  'Samoyed',
#  'Samoyed Mix',
#  'Schipperke',
#  'Schipperke Mix',
#  'Schnauzer Giant',
#  'Schnauzer Giant Mix',
#  'Scottish Fold',
#  'Scottish Fold Mix',
#  'Scottish Terrier',
#  'Scottish Terrier Mix',
#  'Sealyham Terr Mix',
#  'Shetland Sheepdog',
#  'Shetland Sheepdog Mix',
#  'Shiba Inu',
#  'Shiba Inu Mix',
#  'Shih Tzu',
#  'Shih Tzu Mix',
#  'Siamese',
#  'Siamese Mix',
#  'Siberian Husky',
#  'Siberian Husky Mix',
#  'Silky Terrier',
#  'Silky Terrier Mix',
#  'Skye Terrier',
#  'Skye Terrier Mix',
#  'Smooth Fox Terrier',
#  'Smooth Fox Terrier Mix',
#  'Snowshoe',
#  'Snowshoe Mix',
#  'Soft Coated Wheaten Terrier',
#  'Soft Coated Wheaten Terrier Mix',
#  'Spanish Water Dog',
#  'Sphynx',
#  'St. Bernard Rough Coat',
#  'St. Bernard Rough Coat Mix',
#  'St. Bernard Smooth Coat',
#  'St. Bernard Smooth Coat Mix',
#  'Staffordshire',
#  'Staffordshire Mix',
#  'Standard Poodle',
#  'Standard Poodle Mix',
#  'Standard Schnauzer',
#  'Standard Schnauzer Mix',
#  'Swedish Vallhund',
#  'Swedish Vallhund Mix',
#  'Tan Hound',
#  'Tan Hound Mix',
#  'Tibetan Spaniel',
#  'Tibetan Spaniel Mix',
#  'Tibetan Terrier',
#  'Tibetan Terrier Mix',
#  'Tonkinese Mix',
#  'Toy Fox Terrier',
#  'Toy Fox Terrier Mix',
#  'Toy Poodle',
#  'Toy Poodle Mix',
#  'Treeing Cur',
#  'Treeing Cur Mix',
#  'Treeing Tennesse Brindle',
#  'Treeing Tennesse Brindle Mix',
#  'Treeing Walker Coonhound',
#  'Treeing Walker Coonhound Mix',
#  'Turkish Angora Mix',
#  'Turkish Van Mix',
#  'Vizsla',
#  'Vizsla Mix',
#  'Weimaraner',
#  'Weimaraner Mix',
#  'Welsh Springer Spaniel',
#  'Welsh Springer Spaniel Mix',
#  'Welsh Terrier',
#  'Welsh Terrier Mix',
#  'West Highland',
#  'West Highland Mix',
#  'Whippet',
#  'Whippet Mix',
#  'Wire Hair Fox Terrier',
#  'Wire Hair Fox Terrier Mix',
#  'Wirehaired Pointing Griffon Mix',
#  'Yorkshire Terrier',
#  'Yorkshire Terrier Mix',
#  nan}

# %%
breeds = list(set(list(df[(df.is_dog==1)&(df.is_breed2==1)].breed2.unique())
+ list(df[(df.is_dog==1)&(df.is_mix==0)].breed1.unique())
+ [' '.join(breed.split()[:-1]) for breed in df[(df.is_dog==1)&(df.is_mix==1)].breed1.unique()]))

# %%
len(breeds)
# Out:
# 278

# %% [markdown]
# Extracting Breed Info from Dog API

# %%
from dogapi import dogapi

# %%
headers= {'x-api-key':dogapi}

# %%
breed_dict={}
for breed in breeds:
    time.sleep(1)
    response = requests.get('https://api.thedogapi.com/v1/breeds/search?q='+breed, headers=headers)
    breed_dict[breed] = response.json()

# %%
noinfo_breed = [key for key, value in breed_dict.items() if value==[]]
moreinfo_breed = [key for key, value in breed_dict.items() if len(value)>1]

# %%
for breed in noinfo_breeds:
    try: 
    time.sleep(1)
    response = requests.get('https://api.thedogapi.com/v1/breeds/search?q='+breed, headers=headers)
    if response.json():
        breed_dict[breed] = response.json()[0]
    else:
        breed_dict[breed]=None

# %%
test={}
for name in df.found_city.unique():
    if name != 'Outside':
        try:
            time.sleep(1)
            query= "+".join(name.split())+"+TX"
            response = requests.get('https://nominatim.openstreetmap.org/search?q='+query+'&format=jsonv2', headers=headers)
            payload = response.json()
            test[name]={'lat':payload[0]['lat'],'lon':payload[0]['lon']}
        except IndexError:
            test[name]={'lat':None, 'lon':None}
print(test)

# %% [markdown]
# American Kennel Club Webscrape

# %%
html_page = requests.get('http://books.toscrape.com/') 
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
#Webscrape Test
breed='Anatol Shepherd'
time.sleep(1)
info_dict={}
query= '+'.join(breed.split(' ')) + '+breed'
search_page = requests.get('https://www.akc.org/?s='+query)
search_soup = BeautifulSoup(search_page.content, 'html.parser')
breed_link = search_soup.find('a', class_="d-iblock f-11 lh-solid").attrs['href']

info_page = requests.get(breed_link)
info_soup= BeautifulSoup(info_page.content, 'html.parser')
info = info_soup.findAll('span', class_="attribute-list__description")
info_list = [tag.text for tag in info]
for piece in info_list:
    if 'inches' in piece:
        info_dict['height'] = piece
    if 'pounds' in piece:
        info_dict['weight'] = piece
    if 'years' in piece:
        info_dict['lifespan'] = piece
info_dict
# Out:
# {'height': '29 inches (male), 27 inches (female)',
#  'weight': '110-150 pounds (male), 80-120 pounds (female)',
#  'lifespan': '11-13 years'}

# %%
scrape_dict2={}
for breed in noinfo_breed:
    time.sleep(1)
    info_dict={}
    query= '+'.join(breed.split(' ')) + '+breed'
    search_page = requests.get('https://www.akc.org/?s='+query)
    search_soup = BeautifulSoup(search_page.content, 'html.parser')
    breed_link = search_soup.find('a', class_="d-iblock f-11 lh-solid").attrs['href']

    info_page = requests.get(breed_link)
    info_soup= BeautifulSoup(info_page.content, 'html.parser')
    info = info_soup.findAll('span', class_="attribute-list__description")
    info_list = [tag.text for tag in info]
    for piece in info_list:
        if 'inches' in piece:
            info_dict['height'] = piece
        if 'pounds' in piece:
            info_dict['weight'] = piece
        if 'years' in piece:
            info_dict['life_span'] = piece
    scrape_dict2[breed] = info_dict

# %%
scrape_dict2['Black Mouth']=scrape_dict2['Black Mouth Cur']

# %%
breed_dict['Dachshund'][0]['weight']['imperial']
# Out:
# '11 - 32'

# %%
scrape_dict2['Dachshund Stan']['weight'] = breed_dict['Dachshund'][0]['weight']['imperial']
scrape_dict2['Dachshund Stan']['height'] = breed_dict['Dachshund'][0]['height']['imperial']
scrape_dict2['Dachshund Stan']['life_span'] = breed_dict['Dachshund'][0]['life_span']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-377-60be5a45b7b9> in <module>
# ----> 1 scrape_dict2['Dachshund Stan']['weight'] = breed_dict['Dachshund'][0]['weight']['imperial']
#       2 scrape_dict2['Dachshund Stan']['height'] = breed_dict['Dachshund'][0]['height']['imperial']
#       3 scrape_dict2['Dachshund Stan']['life_span'] = breed_dict['Dachshund'][0]['life_span']
#
# TypeError: string indices must be integers

# %%
noinfo_dict = scrape_dict2

# %% [markdown]
# Data Cleaning the Webscrape and API Calls

# %%
breed_dict
# Out:
# {'Affenpinscher': [{'weight': {'imperial': '6 - 13', 'metric': '3 - 6'},
#    'height': {'imperial': '9 - 11.5', 'metric': '23 - 29'},
#    'id': 1,
#    'name': 'Affenpinscher',
#    'bred_for': 'Small rodent hunting, lapdog',
#    'breed_group': 'Toy',
#    'life_span': '10 - 12 years',
#    'temperament': 'Stubborn, Curious, Playful, Adventurous, Active, Fun-loving',
#    'origin': 'Germany, France'}],
#  'Afghan': [{'weight': {'imperial': '50 - 60', 'metric': '23 - 27'},
#    'height': {'imperial': '25 - 27', 'metric': '64 - 69'},
#    'id': 2,
#    'name': 'Afghan Hound',
#    'country_code': 'AG',
#    'bred_for': 'Coursing and hunting',
#    'breed_group': 'Hound',
#    'life_span': '10 - 13 years',
#    'temperament': 'Aloof, Clownish, Dignified, Independent, Happy',
#    'origin': 'Afghanistan, Iran, Pakistan'}],
#  'Airedale': [{'weight': {'imperial': '40 - 65', 'metric': '18 - 29'},
#    'height': {'imperial': '21 - 23', 'metric': '53 - 58'},
#    'id': 4,
#    'name': 'Airedale Terrier',
#    'bred_for': 'Badger, otter hunting',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 13 years',
#    'temperament': 'Outgoing, Friendly, Alert, Confident, Intelligent, Courageous',
#    'origin': 'United Kingdom, England'}],
#  'Airedale Terrier': [{'weight': {'imperial': '40 - 65', 'metric': '18 - 29'},
#    'height': {'imperial': '21 - 23', 'metric': '53 - 58'},
#    'id': 4,
#    'name': 'Airedale Terrier',
#    'bred_for': 'Badger, otter hunting',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 13 years',
#    'temperament': 'Outgoing, Friendly, Alert, Confident, Intelligent, Courageous',
#    'origin': 'United Kingdom, England'}],
#  'Akbash': [{'weight': {'imperial': '90 - 120', 'metric': '41 - 54'},
#    'height': {'imperial': '28 - 34', 'metric': '71 - 86'},
#    'id': 5,
#    'name': 'Akbash Dog',
#    'bred_for': 'Sheep guarding',
#    'breed_group': 'Working',
#    'life_span': '10 - 12 years',
#    'temperament': 'Loyal, Independent, Intelligent, Brave',
#    'origin': ''}],
#  'Akita': [{'weight': {'imperial': '65 - 115', 'metric': '29 - 52'},
#    'height': {'imperial': '24 - 28', 'metric': '61 - 71'},
#    'id': 6,
#    'name': 'Akita',
#    'bred_for': 'Hunting bears',
#    'breed_group': 'Working',
#    'life_span': '10 - 14 years',
#    'temperament': 'Docile, Alert, Responsive, Dignified, Composed, Friendly, Receptive, Faithful, Courageous'}],
#  'Alaskan': [{'weight': {'imperial': '38 - 50', 'metric': '17 - 23'},
#    'height': {'imperial': '23 - 26', 'metric': '58 - 66'},
#    'id': 8,
#    'name': 'Alaskan Husky',
#    'bred_for': 'Sled pulling',
#    'breed_group': 'Mixed',
#    'life_span': '10 - 13 years',
#    'temperament': 'Friendly, Energetic, Loyal, Gentle, Confident'},
#   {'weight': {'imperial': '65 - 100', 'metric': '29 - 45'},
#    'height': {'imperial': '23 - 25', 'metric': '58 - 64'},
#    'id': 9,
#    'name': 'Alaskan Malamute',
#    'bred_for': 'Hauling heavy freight, Sled pulling',
#    'breed_group': 'Working',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Affectionate, Devoted, Loyal, Dignified, Playful'}],
#  'Alaskan Husky': [{'weight': {'imperial': '38 - 50', 'metric': '17 - 23'},
#    'height': {'imperial': '23 - 26', 'metric': '58 - 66'},
#    'id': 8,
#    'name': 'Alaskan Husky',
#    'bred_for': 'Sled pulling',
#    'breed_group': 'Mixed',
#    'life_span': '10 - 13 years',
#    'temperament': 'Friendly, Energetic, Loyal, Gentle, Confident'}],
#  'Alaskan Malamute': [{'weight': {'imperial': '65 - 100', 'metric': '29 - 45'},
#    'height': {'imperial': '23 - 25', 'metric': '58 - 64'},
#    'id': 9,
#    'name': 'Alaskan Malamute',
#    'bred_for': 'Hauling heavy freight, Sled pulling',
#    'breed_group': 'Working',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Affectionate, Devoted, Loyal, Dignified, Playful'}],
#  'American': [{'weight': {'imperial': '60 - 120', 'metric': '27 - 54'},
#    'height': {'imperial': '22 - 27', 'metric': '56 - 69'},
#    'id': 10,
#    'name': 'American Bulldog',
#    'breed_group': 'Working',
#    'life_span': '10 - 12 years',
#    'temperament': 'Friendly, Assertive, Energetic, Loyal, Gentle, Confident, Dominant'},
#   {'weight': {'imperial': '30 - 150', 'metric': '14 - 68'},
#    'height': {'imperial': '14 - 17', 'metric': '36 - 43'},
#    'id': 11,
#    'name': 'American Bully',
#    'country_code': 'US',
#    'bred_for': 'Family companion dog',
#    'breed_group': '',
#    'life_span': '8 – 15 years',
#    'temperament': 'Strong Willed, Stubborn, Friendly, Clownish, Affectionate, Loyal, Obedient, Intelligent, Courageous'},
#   {'weight': {'imperial': '20 - 40', 'metric': '9 - 18'},
#    'height': {'imperial': '15 - 19', 'metric': '38 - 48'},
#    'id': 12,
#    'name': 'American Eskimo Dog',
#    'country_code': 'US',
#    'bred_for': 'Circus performer',
#    'breed_group': 'Non-Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Alert, Reserved, Intelligent, Protective'},
#   {'weight': {'imperial': '7 - 10', 'metric': '3 - 5'},
#    'height': {'imperial': '9 - 12', 'metric': '23 - 30'},
#    'id': 13,
#    'name': 'American Eskimo Dog (Miniature)',
#    'country_code': 'US',
#    'bred_for': 'Companionship',
#    'life_span': '13 – 15 years',
#    'temperament': 'Friendly, Alert, Reserved, Intelligent, Protective'},
#   {'weight': {'imperial': '65 - 75', 'metric': '29 - 34'},
#    'height': {'imperial': '21 - 28', 'metric': '53 - 71'},
#    'id': 14,
#    'name': 'American Foxhound',
#    'country_code': 'US',
#    'bred_for': 'Fox hunting, scent hound',
#    'breed_group': 'Hound',
#    'life_span': '8 - 15 years',
#    'temperament': 'Kind, Sweet-Tempered, Loyal, Independent, Intelligent, Loving'},
#   {'weight': {'imperial': '30 - 60', 'metric': '14 - 27'},
#    'height': {'imperial': '17 - 21', 'metric': '43 - 53'},
#    'id': 15,
#    'name': 'American Pit Bull Terrier',
#    'country_code': 'US',
#    'bred_for': 'Fighting',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 15 years',
#    'temperament': 'Strong Willed, Stubborn, Friendly, Clownish, Affectionate, Loyal, Obedient, Intelligent, Courageous'},
#   {'weight': {'imperial': '50 - 60', 'metric': '23 - 27'},
#    'height': {'imperial': '17 - 19', 'metric': '43 - 48'},
#    'id': 16,
#    'name': 'American Staffordshire Terrier',
#    'country_code': 'US',
#    'bred_for': '',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 15 years',
#    'temperament': 'Tenacious, Friendly, Devoted, Loyal, Attentive, Courageous'},
#   {'weight': {'imperial': '25 - 45', 'metric': '11 - 20'},
#    'height': {'imperial': '15 - 18', 'metric': '38 - 46'},
#    'id': 17,
#    'name': 'American Water Spaniel',
#    'country_code': 'US',
#    'bred_for': 'Bird flushing and retrieving',
#    'breed_group': 'Sporting',
#    'life_span': '10 - 12 years',
#    'temperament': 'Friendly, Energetic, Obedient, Intelligent, Protective, Trainable'},
#   {'weight': {'imperial': '20 - 30', 'metric': '9 - 14'},
#    'height': {'imperial': '14 - 15', 'metric': '36 - 38'},
#    'id': 87,
#    'name': 'Cocker Spaniel (American)',
#    'bred_for': 'Hunting the American woodcock',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Outgoing, Sociable, Trusting, Joyful, Even Tempered, Merry'},
#   {'weight': {'imperial': '20 - 40', 'metric': '9 - 18'},
#    'height': {'imperial': '13 - 18', 'metric': '33 - 46'},
#    'id': 165,
#    'name': 'Miniature American Shepherd',
#    'breed_group': 'Herding',
#    'life_span': '12 - 15 years',
#    'temperament': 'Energetic, Loyal, Intelligent, Trainable'}],
#  'American Bulldog': [{'weight': {'imperial': '60 - 120', 'metric': '27 - 54'},
#    'height': {'imperial': '22 - 27', 'metric': '56 - 69'},
#    'id': 10,
#    'name': 'American Bulldog',
#    'breed_group': 'Working',
#    'life_span': '10 - 12 years',
#    'temperament': 'Friendly, Assertive, Energetic, Loyal, Gentle, Confident, Dominant'}],
#  'American Eskimo': [{'weight': {'imperial': '20 - 40', 'metric': '9 - 18'},
#    'height': {'imperial': '15 - 19', 'metric': '38 - 48'},
#    'id': 12,
#    'name': 'American Eskimo Dog',
#    'country_code': 'US',
#    'bred_for': 'Circus performer',
#    'breed_group': 'Non-Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Alert, Reserved, Intelligent, Protective'},
#   {'weight': {'imperial': '7 - 10', 'metric': '3 - 5'},
#    'height': {'imperial': '9 - 12', 'metric': '23 - 30'},
#    'id': 13,
#    'name': 'American Eskimo Dog (Miniature)',
#    'country_code': 'US',
#    'bred_for': 'Companionship',
#    'life_span': '13 – 15 years',
#    'temperament': 'Friendly, Alert, Reserved, Intelligent, Protective'}],
#  'American Foxhound': [{'weight': {'imperial': '65 - 75', 'metric': '29 - 34'},
#    'height': {'imperial': '21 - 28', 'metric': '53 - 71'},
#    'id': 14,
#    'name': 'American Foxhound',
#    'country_code': 'US',
#    'bred_for': 'Fox hunting, scent hound',
#    'breed_group': 'Hound',
#    'life_span': '8 - 15 years',
#    'temperament': 'Kind, Sweet-Tempered, Loyal, Independent, Intelligent, Loving'}],
#  'American Pit Bull': [{'weight': {'imperial': '30 - 60', 'metric': '14 - 27'},
#    'height': {'imperial': '17 - 21', 'metric': '43 - 53'},
#    'id': 15,
#    'name': 'American Pit Bull Terrier',
#    'country_code': 'US',
#    'bred_for': 'Fighting',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 15 years',
#    'temperament': 'Strong Willed, Stubborn, Friendly, Clownish, Affectionate, Loyal, Obedient, Intelligent, Courageous'}],
#  'American Pit Bull Terrier': [{'weight': {'imperial': '30 - 60',
#     'metric': '14 - 27'},
#    'height': {'imperial': '17 - 21', 'metric': '43 - 53'},
#    'id': 15,
#    'name': 'American Pit Bull Terrier',
#    'country_code': 'US',
#    'bred_for': 'Fighting',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 15 years',
#    'temperament': 'Strong Willed, Stubborn, Friendly, Clownish, Affectionate, Loyal, Obedient, Intelligent, Courageous'}],
#  'American Staffordshire': [{'weight': {'imperial': '50 - 60',
#     'metric': '23 - 27'},
#    'height': {'imperial': '17 - 19', 'metric': '43 - 48'},
#    'id': 16,
#    'name': 'American Staffordshire Terrier',
#    'country_code': 'US',
#    'bred_for': '',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 15 years',
#    'temperament': 'Tenacious, Friendly, Devoted, Loyal, Attentive, Courageous'}],
#  'American Staffordshire Terrier': [{'weight': {'imperial': '50 - 60',
#     'metric': '23 - 27'},
#    'height': {'imperial': '17 - 19', 'metric': '43 - 48'},
#    'id': 16,
#    'name': 'American Staffordshire Terrier',
#    'country_code': 'US',
#    'bred_for': '',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 15 years',
#    'temperament': 'Tenacious, Friendly, Devoted, Loyal, Attentive, Courageous'}],
#  'Anatol': [{'weight': {'imperial': '80 - 150', 'metric': '36 - 68'},
#    'height': {'imperial': '27 - 29', 'metric': '69 - 74'},
#    'id': 18,
#    'name': 'Anatolian Shepherd Dog',
#    'bred_for': 'Livestock herding',
#    'breed_group': 'Working',
#    'life_span': '11 - 13 years',
#    'temperament': 'Steady, Bold, Independent, Confident, Intelligent, Proud'}],
#  'Anatol Shepherd': [],
#  'Australian': [{'weight': {'imperial': '44 - 62', 'metric': '20 - 28'},
#    'height': {'imperial': '17 - 20', 'metric': '43 - 51'},
#    'id': 21,
#    'name': 'Australian Cattle Dog',
#    'country_code': 'AU',
#    'bred_for': 'Cattle herding, herding trials',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Cautious, Energetic, Loyal, Obedient, Protective, Brave'},
#   {'weight': {'imperial': '31 - 46', 'metric': '14 - 21'},
#    'height': {'imperial': '17 - 20', 'metric': '43 - 51'},
#    'id': 22,
#    'name': 'Australian Kelpie',
#    'country_code': 'AU',
#    'bred_for': 'Farm dog, Cattle herding',
#    'breed_group': 'Herding',
#    'life_span': '10 - 13 years',
#    'temperament': 'Friendly, Energetic, Alert, Loyal, Intelligent, Eager'},
#   {'weight': {'imperial': '35 - 65', 'metric': '16 - 29'},
#    'height': {'imperial': '18 - 23', 'metric': '46 - 58'},
#    'id': 23,
#    'name': 'Australian Shepherd',
#    'country_code': 'AU',
#    'bred_for': 'Sheep herding',
#    'breed_group': 'Herding',
#    'life_span': '12 - 16 years',
#    'temperament': 'Good-natured, Affectionate, Intelligent, Active, Protective'},
#   {'weight': {'imperial': '14 - 16', 'metric': '6 - 7'},
#    'height': {'imperial': '10 - 11', 'metric': '25 - 28'},
#    'id': 24,
#    'name': 'Australian Terrier',
#    'country_code': 'AU',
#    'bred_for': 'Cattle herdering, hunting snakes and rodents',
#    'breed_group': 'Terrier',
#    'life_span': '15 years',
#    'temperament': 'Spirited, Alert, Loyal, Companionable, Even Tempered, Courageous'}],
#  'Australian Cattle': [{'weight': {'imperial': '44 - 62', 'metric': '20 - 28'},
#    'height': {'imperial': '17 - 20', 'metric': '43 - 51'},
#    'id': 21,
#    'name': 'Australian Cattle Dog',
#    'country_code': 'AU',
#    'bred_for': 'Cattle herding, herding trials',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Cautious, Energetic, Loyal, Obedient, Protective, Brave'}],
#  'Australian Cattle Dog': [{'weight': {'imperial': '44 - 62',
#     'metric': '20 - 28'},
#    'height': {'imperial': '17 - 20', 'metric': '43 - 51'},
#    'id': 21,
#    'name': 'Australian Cattle Dog',
#    'country_code': 'AU',
#    'bred_for': 'Cattle herding, herding trials',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Cautious, Energetic, Loyal, Obedient, Protective, Brave'}],
#  'Australian Kelpie': [{'weight': {'imperial': '31 - 46', 'metric': '14 - 21'},
#    'height': {'imperial': '17 - 20', 'metric': '43 - 51'},
#    'id': 22,
#    'name': 'Australian Kelpie',
#    'country_code': 'AU',
#    'bred_for': 'Farm dog, Cattle herding',
#    'breed_group': 'Herding',
#    'life_span': '10 - 13 years',
#    'temperament': 'Friendly, Energetic, Alert, Loyal, Intelligent, Eager'}],
#  'Australian Shepherd': [{'weight': {'imperial': '35 - 65',
#     'metric': '16 - 29'},
#    'height': {'imperial': '18 - 23', 'metric': '46 - 58'},
#    'id': 23,
#    'name': 'Australian Shepherd',
#    'country_code': 'AU',
#    'bred_for': 'Sheep herding',
#    'breed_group': 'Herding',
#    'life_span': '12 - 16 years',
#    'temperament': 'Good-natured, Affectionate, Intelligent, Active, Protective'}],
#  'Australian Terrier': [{'weight': {'imperial': '14 - 16', 'metric': '6 - 7'},
#    'height': {'imperial': '10 - 11', 'metric': '25 - 28'},
#    'id': 24,
#    'name': 'Australian Terrier',
#    'country_code': 'AU',
#    'bred_for': 'Cattle herdering, hunting snakes and rodents',
#    'breed_group': 'Terrier',
#    'life_span': '15 years',
#    'temperament': 'Spirited, Alert, Loyal, Companionable, Even Tempered, Courageous'}],
#  'Basenji': [{'weight': {'imperial': '22 - 24', 'metric': '10 - 11'},
#    'height': {'imperial': '16 - 17', 'metric': '41 - 43'},
#    'id': 28,
#    'name': 'Basenji',
#    'bred_for': 'Hunting',
#    'breed_group': 'Hound',
#    'life_span': '10 - 12 years',
#    'temperament': 'Affectionate, Energetic, Alert, Curious, Playful, Intelligent'}],
#  'Basset': [{'weight': {'imperial': '35 - 40', 'metric': '16 - 18'},
#    'height': {'imperial': '13 - 15', 'metric': '33 - 38'},
#    'id': 29,
#    'name': 'Basset Bleu de Gascogne',
#    'bred_for': 'Hunting on foot.',
#    'breed_group': 'Hound',
#    'life_span': '10 - 14 years',
#    'temperament': 'Affectionate, Lively, Agile, Curious, Happy, Active'},
#   {'weight': {'imperial': '50 - 65', 'metric': '23 - 29'},
#    'height': {'imperial': '14', 'metric': '36'},
#    'id': 30,
#    'name': 'Basset Hound',
#    'bred_for': 'Hunting by scent',
#    'breed_group': 'Hound',
#    'life_span': '12 - 15 years',
#    'temperament': 'Tenacious, Friendly, Affectionate, Devoted, Sweet-Tempered, Gentle'},
#   {'weight': {'imperial': '25 - 42', 'metric': '11 - 19'},
#    'height': {'imperial': '13 - 15', 'metric': '33 - 38'},
#    'id': 187,
#    'name': 'Petit Basset Griffon Vendeen',
#    'breed_group': 'Hound',
#    'life_span': '10 - 14 years',
#    'temperament': 'Extroverted, Friendly, Lively, Independent, Happy, Active'}],
#  'Basset Hound': [{'weight': {'imperial': '50 - 65', 'metric': '23 - 29'},
#    'height': {'imperial': '14', 'metric': '36'},
#    'id': 30,
#    'name': 'Basset Hound',
#    'bred_for': 'Hunting by scent',
#    'breed_group': 'Hound',
#    'life_span': '12 - 15 years',
#    'temperament': 'Tenacious, Friendly, Affectionate, Devoted, Sweet-Tempered, Gentle'}],
#  'Beagle': [{'weight': {'imperial': '20 - 35', 'metric': '9 - 16'},
#    'height': {'imperial': '13 - 15', 'metric': '33 - 38'},
#    'id': 31,
#    'name': 'Beagle',
#    'bred_for': 'Rabbit, hare hunting',
#    'breed_group': 'Hound',
#    'life_span': '13 - 16 years',
#    'temperament': 'Amiable, Even Tempered, Excitable, Determined, Gentle, Intelligent'}],
#  'Bearded Collie': [{'weight': {'imperial': '45 - 55', 'metric': '20 - 25'},
#    'height': {'imperial': '20 - 22', 'metric': '51 - 56'},
#    'id': 32,
#    'name': 'Bearded Collie',
#    'bred_for': 'Sheep herding',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Self-confidence, Hardy, Lively, Alert, Intelligent, Active'}],
#  'Beauceron': [{'weight': {'imperial': '80 - 110', 'metric': '36 - 50'},
#    'height': {'imperial': '24 - 27.5', 'metric': '61 - 70'},
#    'id': 33,
#    'name': 'Beauceron',
#    'bred_for': 'Boar herding, hunting, guarding',
#    'breed_group': 'Herding',
#    'life_span': '10 - 12 years',
#    'temperament': 'Fearless, Friendly, Intelligent, Protective, Calm'}],
#  'Bedlington Terr': [{'weight': {'imperial': '17 - 23', 'metric': '8 - 10'},
#    'height': {'imperial': '15 - 16', 'metric': '38 - 41'},
#    'id': 34,
#    'name': 'Bedlington Terrier',
#    'bred_for': 'Killing rat, badger, other vermin',
#    'breed_group': 'Terrier',
#    'life_span': '14 - 16 years',
#    'temperament': 'Affectionate, Spirited, Intelligent, Good-tempered'}],
#  'Belgian': [{'weight': {'imperial': '45 - 65', 'metric': '20 - 29'},
#    'height': {'imperial': '22 - 26', 'metric': '56 - 66'},
#    'id': 35,
#    'name': 'Belgian Laekenois',
#    'bred_for': 'Herding sheep at the Royal Castle of Laeken, Guarding linen that is placed in fields to dry, Messenger Dog.',
#    'breed_group': 'Herding',
#    'life_span': '10 - 12 years',
#    'temperament': 'Energetic, Lively, Alert, Active, Protective, Watchful'},
#   {'weight': {'imperial': '40 - 80', 'metric': '18 - 36'},
#    'height': {'imperial': '22 - 26', 'metric': '56 - 66'},
#    'id': 36,
#    'name': 'Belgian Malinois',
#    'bred_for': 'Stock herding',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Watchful, Alert, Stubborn, Friendly, Confident, Hard-working, Active, Protective'},
#   {'weight': {'imperial': '40 - 75', 'metric': '18 - 34'},
#    'height': {'imperial': '22 - 26', 'metric': '56 - 66'},
#    'id': 37,
#    'name': 'Belgian Sheepdog',
#    'bred_for': 'Stock herding',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Affectionate, Loyal, Intelligent, Dominant, Active, Powerful'},
#   {'weight': {'imperial': '40 - 65', 'metric': '18 - 29'},
#    'height': {'imperial': '22 - 26', 'metric': '56 - 66'},
#    'id': 38,
#    'name': 'Belgian Tervuren',
#    'bred_for': 'Guarding, Drafting, Police work.',
#    'breed_group': 'Herding',
#    'life_span': '10 - 12 years',
#    'temperament': 'Energetic, Alert, Loyal, Intelligent, Attentive, Protective'}],
#  'Belgian Malinois': [{'weight': {'imperial': '40 - 80', 'metric': '18 - 36'},
#    'height': {'imperial': '22 - 26', 'metric': '56 - 66'},
#    'id': 36,
#    'name': 'Belgian Malinois',
#    'bred_for': 'Stock herding',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Watchful, Alert, Stubborn, Friendly, Confident, Hard-working, Active, Protective'}],
#  'Belgian Sheepdog': [{'weight': {'imperial': '40 - 75', 'metric': '18 - 34'},
#    'height': {'imperial': '22 - 26', 'metric': '56 - 66'},
#    'id': 37,
#    'name': 'Belgian Sheepdog',
#    'bred_for': 'Stock herding',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Affectionate, Loyal, Intelligent, Dominant, Active, Powerful'}],
#  'Belgian Tervuren': [{'weight': {'imperial': '40 - 65', 'metric': '18 - 29'},
#    'height': {'imperial': '22 - 26', 'metric': '56 - 66'},
#    'id': 38,
#    'name': 'Belgian Tervuren',
#    'bred_for': 'Guarding, Drafting, Police work.',
#    'breed_group': 'Herding',
#    'life_span': '10 - 12 years',
#    'temperament': 'Energetic, Alert, Loyal, Intelligent, Attentive, Protective'}],
#  'Bernese Mountain': [{'weight': {'imperial': '65 - 120', 'metric': '29 - 54'},
#    'height': {'imperial': '23 - 27.5', 'metric': '58 - 70'},
#    'id': 41,
#    'name': 'Bernese Mountain Dog',
#    'bred_for': 'Draft work',
#    'breed_group': 'Working',
#    'life_span': '7 - 10 years',
#    'temperament': 'Affectionate, Loyal, Intelligent, Faithful'}],
#  'Bernese Mountain Dog': [{'weight': {'imperial': '65 - 120',
#     'metric': '29 - 54'},
#    'height': {'imperial': '23 - 27.5', 'metric': '58 - 70'},
#    'id': 41,
#    'name': 'Bernese Mountain Dog',
#    'bred_for': 'Draft work',
#    'breed_group': 'Working',
#    'life_span': '7 - 10 years',
#    'temperament': 'Affectionate, Loyal, Intelligent, Faithful'}],
#  'Bichon': [{'weight': {'imperial': '10 - 18', 'metric': '5 - 8'},
#    'height': {'imperial': '9.5 - 11.5', 'metric': '24 - 29'},
#    'id': 42,
#    'name': 'Bichon Frise',
#    'bred_for': 'Companion',
#    'breed_group': 'Non-Sporting',
#    'life_span': '15 years',
#    'temperament': 'Feisty, Affectionate, Cheerful, Playful, Gentle, Sensitive'}],
#  'Bichon Frise': [{'weight': {'imperial': '10 - 18', 'metric': '5 - 8'},
#    'height': {'imperial': '9.5 - 11.5', 'metric': '24 - 29'},
#    'id': 42,
#    'name': 'Bichon Frise',
#    'bred_for': 'Companion',
#    'breed_group': 'Non-Sporting',
#    'life_span': '15 years',
#    'temperament': 'Feisty, Affectionate, Cheerful, Playful, Gentle, Sensitive'}],
#  'Black Mouth': [],
#  'Black Mouth Cur': [],
#  'Bloodhound': [{'weight': {'imperial': '80 - 110', 'metric': '36 - 50'},
#    'height': {'imperial': '23 - 27', 'metric': '58 - 69'},
#    'id': 45,
#    'name': 'Bloodhound',
#    'bred_for': 'Trailing',
#    'breed_group': 'Hound',
#    'life_span': '8 - 10 years',
#    'temperament': 'Stubborn, Affectionate, Gentle, Even Tempered'}],
#  'Blue': [{'weight': {'imperial': '55 - 90', 'metric': '25 - 41'},
#    'height': {'imperial': '18 - 24', 'metric': '46 - 61'},
#    'id': 7,
#    'name': 'Alapaha Blue Blood Bulldog',
#    'description': "The Alapaha Blue Blood Bulldog is a well-developed, exaggerated bulldog with a broad head and natural drop ears. The prominent muzzle is covered by loose upper lips. The prominent eyes are set well apart. The Alapaha's coat is relatively short and fairly stiff. Preferred colors are blue merle, brown merle, or red merle all trimmed in white or chocolate and white. Also preferred are the glass eyes (blue) or marble eyes (brown and blue mixed in a single eye). The ears and tail are never trimmed or docked. The body is sturdy and very muscular. The well-muscled hips are narrower than the chest. The straight back is as long as the dog is high at the shoulders. The dewclaws are never removed and the feet are cat-like.",
#    'bred_for': 'Guarding',
#    'breed_group': 'Mixed',
#    'life_span': '12 - 13 years',
#    'history': '',
#    'temperament': 'Loving, Protective, Trainable, Dutiful, Responsible'},
#   {'weight': {'imperial': '55 - 70', 'metric': '25 - 32'},
#    'height': {'imperial': '22 - 24', 'metric': '56 - 61'},
#    'id': 46,
#    'name': 'Blue Picardy Spaniel',
#    'bred_for': 'Ability to locate and retrieve game in harsh and adverse terrain and conditions',
#    'breed_group': 'Sporting',
#    'life_span': '9 - 13 years',
#    'temperament': 'Playful, Gentle, Adaptable, Active, Protective, Calm'},
#   {'weight': {'imperial': '45 - 80', 'metric': '20 - 36'},
#    'height': {'imperial': '21 - 27', 'metric': '53 - 69'},
#    'id': 47,
#    'name': 'Bluetick Coonhound',
#    'bred_for': 'Hunting with a superior sense of smell.',
#    'breed_group': 'Hound',
#    'life_span': '12 - 14 years',
#    'temperament': 'Friendly, Intelligent, Active'},
#   {'weight': {'imperial': '33 - 40', 'metric': '15 - 18'},
#    'height': {'imperial': '17.5 - 19.5', 'metric': '44 - 50'},
#    'id': 143,
#    'name': 'Kerry Blue Terrier',
#    'bred_for': 'Working dog, herding cattle and sheep. Hunting small game and birds, killing rodents, and guarding his homestead',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 15 years',
#    'temperament': 'Strong Willed, Affectionate, Spirited, Alert, Loyal, Gentle'}],
#  'Blue Lacy': [],
#  'Bluetick': [{'weight': {'imperial': '45 - 80', 'metric': '20 - 36'},
#    'height': {'imperial': '21 - 27', 'metric': '53 - 69'},
#    'id': 47,
#    'name': 'Bluetick Coonhound',
#    'bred_for': 'Hunting with a superior sense of smell.',
#    'breed_group': 'Hound',
#    'life_span': '12 - 14 years',
#    'temperament': 'Friendly, Intelligent, Active'}],
#  'Bluetick Hound': [],
#  'Boerboel': [{'weight': {'imperial': '110 - 200', 'metric': '50 - 91'},
#    'height': {'imperial': '22 - 27', 'metric': '56 - 69'},
#    'id': 48,
#    'name': 'Boerboel',
#    'bred_for': 'Guarding the homestead, farm work.',
#    'breed_group': 'Working',
#    'life_span': '10 - 12 years',
#    'temperament': 'Obedient, Confident, Intelligent, Dominant, Territorial'}],
#  'Border': [{'weight': {'imperial': '30 - 45', 'metric': '14 - 20'},
#    'height': {'imperial': '18 - 22', 'metric': '46 - 56'},
#    'id': 50,
#    'name': 'Border Collie',
#    'bred_for': 'Sheep herder',
#    'breed_group': 'Herding',
#    'life_span': '12 - 16 years',
#    'temperament': 'Tenacious, Keen, Energetic, Responsive, Alert, Intelligent'},
#   {'weight': {'imperial': '11.5 - 15.5', 'metric': '5 - 7'},
#    'height': {'imperial': '11 - 16', 'metric': '28 - 41'},
#    'id': 51,
#    'name': 'Border Terrier',
#    'bred_for': 'Fox bolting, ratting',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 14 years',
#    'temperament': 'Fearless, Affectionate, Alert, Obedient, Intelligent, Even Tempered'}],
#  'Border Collie': [{'weight': {'imperial': '30 - 45', 'metric': '14 - 20'},
#    'height': {'imperial': '18 - 22', 'metric': '46 - 56'},
#    'id': 50,
#    'name': 'Border Collie',
#    'bred_for': 'Sheep herder',
#    'breed_group': 'Herding',
#    'life_span': '12 - 16 years',
#    'temperament': 'Tenacious, Keen, Energetic, Responsive, Alert, Intelligent'}],
#  'Border Terrier': [{'weight': {'imperial': '11.5 - 15.5', 'metric': '5 - 7'},
#    'height': {'imperial': '11 - 16', 'metric': '28 - 41'},
#    'id': 51,
#    'name': 'Border Terrier',
#    'bred_for': 'Fox bolting, ratting',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 14 years',
#    'temperament': 'Fearless, Affectionate, Alert, Obedient, Intelligent, Even Tempered'}],
#  'Borzoi': [{'weight': {'imperial': '55 - 120', 'metric': '25 - 54'},
#    'height': {'imperial': '26 - 28', 'metric': '66 - 71'},
#    'id': 52,
#    'name': 'Borzoi',
#    'bred_for': 'Coursing wolves',
#    'breed_group': 'Hound',
#    'life_span': '10 - 13 years',
#    'temperament': 'Respectful, Independent, Athletic, Gentle, Intelligent, Quiet'}],
#  'Boston': [{'weight': {'imperial': '10 - 25', 'metric': '5 - 11'},
#    'height': {'imperial': '16 - 17', 'metric': '41 - 43'},
#    'id': 53,
#    'name': 'Boston Terrier',
#    'bred_for': 'Ratting, Companionship',
#    'breed_group': 'Non-Sporting',
#    'life_span': '11 - 13 years',
#    'temperament': 'Friendly, Lively, Intelligent'}],
#  'Boston Terrier': [{'weight': {'imperial': '10 - 25', 'metric': '5 - 11'},
#    'height': {'imperial': '16 - 17', 'metric': '41 - 43'},
#    'id': 53,
#    'name': 'Boston Terrier',
#    'bred_for': 'Ratting, Companionship',
#    'breed_group': 'Non-Sporting',
#    'life_span': '11 - 13 years',
#    'temperament': 'Friendly, Lively, Intelligent'}],
#  'Boxer': [{'weight': {'imperial': '50 - 70', 'metric': '23 - 32'},
#    'height': {'imperial': '21.5 - 25', 'metric': '55 - 64'},
#    'id': 55,
#    'name': 'Boxer',
#    'bred_for': 'Bull-baiting, guardian',
#    'breed_group': 'Working',
#    'life_span': '8 - 10 years',
#    'temperament': 'Devoted, Fearless, Friendly, Cheerful, Energetic, Loyal, Playful, Confident, Intelligent, Bright, Brave, Calm'}],
#  'Boykin': [{'weight': {'imperial': '25 - 40', 'metric': '11 - 18'},
#    'height': {'imperial': '14 - 18', 'metric': '36 - 46'},
#    'id': 56,
#    'name': 'Boykin Spaniel',
#    'bred_for': 'Turkey retrieving',
#    'breed_group': 'Sporting',
#    'life_span': '10 - 14 years',
#    'temperament': 'Friendly, Energetic, Companionable, Intelligent, Eager, Trainable'}],
#  'Boykin Span': [{'weight': {'imperial': '25 - 40', 'metric': '11 - 18'},
#    'height': {'imperial': '14 - 18', 'metric': '36 - 46'},
#    'id': 56,
#    'name': 'Boykin Spaniel',
#    'bred_for': 'Turkey retrieving',
#    'breed_group': 'Sporting',
#    'life_span': '10 - 14 years',
#    'temperament': 'Friendly, Energetic, Companionable, Intelligent, Eager, Trainable'}],
#  'Brittany': [{'weight': {'imperial': '30 - 45', 'metric': '14 - 20'},
#    'height': {'imperial': '17.5 - 20.5', 'metric': '44 - 52'},
#    'id': 59,
#    'name': 'Brittany',
#    'bred_for': 'Pointing, retrieving',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 14 years',
#    'temperament': 'Agile, Adaptable, Quick, Intelligent, Attentive, Happy'}],
#  'Bruss': [{'weight': {'imperial': '8 - 12', 'metric': '4 - 5'},
#    'height': {'imperial': '10', 'metric': '25'},
#    'id': 60,
#    'name': 'Brussels Griffon',
#    'bred_for': 'Vermin control, Companionship',
#    'breed_group': 'Toy',
#    'life_span': '12 - 15 years',
#    'temperament': 'Self-important, Inquisitive, Alert, Companionable, Sensitive, Watchful'}],
#  'Bruss Griffon': [],
#  'Bull': [{'weight': {'imperial': '55 - 90', 'metric': '25 - 41'},
#    'height': {'imperial': '18 - 24', 'metric': '46 - 61'},
#    'id': 7,
#    'name': 'Alapaha Blue Blood Bulldog',
#    'description': "The Alapaha Blue Blood Bulldog is a well-developed, exaggerated bulldog with a broad head and natural drop ears. The prominent muzzle is covered by loose upper lips. The prominent eyes are set well apart. The Alapaha's coat is relatively short and fairly stiff. Preferred colors are blue merle, brown merle, or red merle all trimmed in white or chocolate and white. Also preferred are the glass eyes (blue) or marble eyes (brown and blue mixed in a single eye). The ears and tail are never trimmed or docked. The body is sturdy and very muscular. The well-muscled hips are narrower than the chest. The straight back is as long as the dog is high at the shoulders. The dewclaws are never removed and the feet are cat-like.",
#    'bred_for': 'Guarding',
#    'breed_group': 'Mixed',
#    'life_span': '12 - 13 years',
#    'history': '',
#    'temperament': 'Loving, Protective, Trainable, Dutiful, Responsible'},
#   {'weight': {'imperial': '60 - 120', 'metric': '27 - 54'},
#    'height': {'imperial': '22 - 27', 'metric': '56 - 69'},
#    'id': 10,
#    'name': 'American Bulldog',
#    'breed_group': 'Working',
#    'life_span': '10 - 12 years',
#    'temperament': 'Friendly, Assertive, Energetic, Loyal, Gentle, Confident, Dominant'},
#   {'weight': {'imperial': '30 - 150', 'metric': '14 - 68'},
#    'height': {'imperial': '14 - 17', 'metric': '36 - 43'},
#    'id': 11,
#    'name': 'American Bully',
#    'country_code': 'US',
#    'bred_for': 'Family companion dog',
#    'breed_group': '',
#    'life_span': '8 – 15 years',
#    'temperament': 'Strong Willed, Stubborn, Friendly, Clownish, Affectionate, Loyal, Obedient, Intelligent, Courageous'},
#   {'weight': {'imperial': '30 - 60', 'metric': '14 - 27'},
#    'height': {'imperial': '17 - 21', 'metric': '43 - 53'},
#    'id': 15,
#    'name': 'American Pit Bull Terrier',
#    'country_code': 'US',
#    'bred_for': 'Fighting',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 15 years',
#    'temperament': 'Strong Willed, Stubborn, Friendly, Clownish, Affectionate, Loyal, Obedient, Intelligent, Courageous'},
#   {'weight': {'imperial': '50 - 70', 'metric': '23 - 32'},
#    'height': {'imperial': '21 - 22', 'metric': '53 - 56'},
#    'id': 61,
#    'name': 'Bull Terrier',
#    'bred_for': 'Bull baiting, Fighting',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 12 years',
#    'temperament': 'Trainable, Protective, Sweet-Tempered, Keen, Active'},
#   {'weight': {'imperial': '25 - 33', 'metric': '11 - 15'},
#    'height': {'imperial': '10 - 14', 'metric': '25 - 36'},
#    'id': 62,
#    'name': 'Bull Terrier (Miniature)',
#    'bred_for': "An elegant man's fashion statement",
#    'life_span': '11 – 14 years',
#    'temperament': 'Trainable, Protective, Sweet-Tempered, Keen, Active, Territorial'},
#   {'weight': {'imperial': '40 - 50', 'metric': '18 - 23'},
#    'height': {'imperial': '12 - 16', 'metric': '30 - 41'},
#    'id': 63,
#    'name': 'Bulldog',
#    'bred_for': 'Bull baiting',
#    'breed_group': 'Non-Sporting',
#    'life_span': '8 - 10 years',
#    'temperament': 'Gregarious, Docile, Willful, Friendly'},
#   {'weight': {'imperial': '100 - 130', 'metric': '45 - 59'},
#    'height': {'imperial': '24 - 27', 'metric': '61 - 69'},
#    'id': 64,
#    'name': 'Bullmastiff',
#    'bred_for': 'Estate guardian',
#    'breed_group': 'Working',
#    'life_span': '8 - 12 years',
#    'temperament': 'Docile, Reliable, Devoted, Alert, Loyal, Reserved, Loving, Protective, Powerful, Calm, Courageous'},
#   {'weight': {'imperial': '28', 'metric': '13'},
#    'height': {'imperial': '11 - 12', 'metric': '28 - 30'},
#    'id': 113,
#    'name': 'French Bulldog',
#    'bred_for': 'Lapdog',
#    'breed_group': 'Non-Sporting',
#    'life_span': '9 - 11 years',
#    'temperament': 'Playful, Affectionate, Keen, Sociable, Lively, Alert, Easygoing, Patient, Athletic, Bright'},
#   {'weight': {'imperial': '20 - 35', 'metric': '9 - 16'},
#    'height': {'imperial': '10 - 14', 'metric': '25 - 36'},
#    'id': 166,
#    'name': 'Miniature Bull Terrier',
#    'bred_for': 'Ratting',
#    'breed_group': 'Terrier',
#    'life_span': '11 or 12 years',
#    'temperament': 'Trainable, Protective, Sweet-Tempered, Keen, Active'},
#   {'weight': {'imperial': '65 – 85', 'metric': 'NaN'},
#    'height': {'imperial': '15 - 19', 'metric': '38 - 48'},
#    'id': 179,
#    'name': 'Olde English Bulldogge',
#    'life_span': '9 – 14 years',
#    'temperament': 'Friendly, Alert, Confident, Loving, Courageous, Strong'},
#   {'weight': {'imperial': '24 - 38', 'metric': '11 - 17'},
#    'height': {'imperial': '14 - 16', 'metric': '36 - 41'},
#    'id': 238,
#    'name': 'Staffordshire Bull Terrier',
#    'bred_for': '',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 14 years',
#    'temperament': 'Reliable, Fearless, Bold, Affectionate, Loyal, Intelligent, Courageous'}],
#  'Bull Terrier': [{'weight': {'imperial': '30 - 60', 'metric': '14 - 27'},
#    'height': {'imperial': '17 - 21', 'metric': '43 - 53'},
#    'id': 15,
#    'name': 'American Pit Bull Terrier',
#    'country_code': 'US',
#    'bred_for': 'Fighting',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 15 years',
#    'temperament': 'Strong Willed, Stubborn, Friendly, Clownish, Affectionate, Loyal, Obedient, Intelligent, Courageous'},
#   {'weight': {'imperial': '50 - 70', 'metric': '23 - 32'},
#    'height': {'imperial': '21 - 22', 'metric': '53 - 56'},
#    'id': 61,
#    'name': 'Bull Terrier',
#    'bred_for': 'Bull baiting, Fighting',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 12 years',
#    'temperament': 'Trainable, Protective, Sweet-Tempered, Keen, Active'},
#   {'weight': {'imperial': '25 - 33', 'metric': '11 - 15'},
#    'height': {'imperial': '10 - 14', 'metric': '25 - 36'},
#    'id': 62,
#    'name': 'Bull Terrier (Miniature)',
#    'bred_for': "An elegant man's fashion statement",
#    'life_span': '11 – 14 years',
#    'temperament': 'Trainable, Protective, Sweet-Tempered, Keen, Active, Territorial'},
#   {'weight': {'imperial': '20 - 35', 'metric': '9 - 16'},
#    'height': {'imperial': '10 - 14', 'metric': '25 - 36'},
#    'id': 166,
#    'name': 'Miniature Bull Terrier',
#    'bred_for': 'Ratting',
#    'breed_group': 'Terrier',
#    'life_span': '11 or 12 years',
#    'temperament': 'Trainable, Protective, Sweet-Tempered, Keen, Active'},
#   {'weight': {'imperial': '24 - 38', 'metric': '11 - 17'},
#    'height': {'imperial': '14 - 16', 'metric': '36 - 41'},
#    'id': 238,
#    'name': 'Staffordshire Bull Terrier',
#    'bred_for': '',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 14 years',
#    'temperament': 'Reliable, Fearless, Bold, Affectionate, Loyal, Intelligent, Courageous'}],
#  'Bull Terrier Miniature': [],
#  'Bulldog': [{'weight': {'imperial': '55 - 90', 'metric': '25 - 41'},
#    'height': {'imperial': '18 - 24', 'metric': '46 - 61'},
#    'id': 7,
#    'name': 'Alapaha Blue Blood Bulldog',
#    'description': "The Alapaha Blue Blood Bulldog is a well-developed, exaggerated bulldog with a broad head and natural drop ears. The prominent muzzle is covered by loose upper lips. The prominent eyes are set well apart. The Alapaha's coat is relatively short and fairly stiff. Preferred colors are blue merle, brown merle, or red merle all trimmed in white or chocolate and white. Also preferred are the glass eyes (blue) or marble eyes (brown and blue mixed in a single eye). The ears and tail are never trimmed or docked. The body is sturdy and very muscular. The well-muscled hips are narrower than the chest. The straight back is as long as the dog is high at the shoulders. The dewclaws are never removed and the feet are cat-like.",
#    'bred_for': 'Guarding',
#    'breed_group': 'Mixed',
#    'life_span': '12 - 13 years',
#    'history': '',
#    'temperament': 'Loving, Protective, Trainable, Dutiful, Responsible'},
#   {'weight': {'imperial': '60 - 120', 'metric': '27 - 54'},
#    'height': {'imperial': '22 - 27', 'metric': '56 - 69'},
#    'id': 10,
#    'name': 'American Bulldog',
#    'breed_group': 'Working',
#    'life_span': '10 - 12 years',
#    'temperament': 'Friendly, Assertive, Energetic, Loyal, Gentle, Confident, Dominant'},
#   {'weight': {'imperial': '40 - 50', 'metric': '18 - 23'},
#    'height': {'imperial': '12 - 16', 'metric': '30 - 41'},
#    'id': 63,
#    'name': 'Bulldog',
#    'bred_for': 'Bull baiting',
#    'breed_group': 'Non-Sporting',
#    'life_span': '8 - 10 years',
#    'temperament': 'Gregarious, Docile, Willful, Friendly'},
#   {'weight': {'imperial': '28', 'metric': '13'},
#    'height': {'imperial': '11 - 12', 'metric': '28 - 30'},
#    'id': 113,
#    'name': 'French Bulldog',
#    'bred_for': 'Lapdog',
#    'breed_group': 'Non-Sporting',
#    'life_span': '9 - 11 years',
#    'temperament': 'Playful, Affectionate, Keen, Sociable, Lively, Alert, Easygoing, Patient, Athletic, Bright'},
#   {'weight': {'imperial': '65 – 85', 'metric': 'NaN'},
#    'height': {'imperial': '15 - 19', 'metric': '38 - 48'},
#    'id': 179,
#    'name': 'Olde English Bulldogge',
#    'life_span': '9 – 14 years',
#    'temperament': 'Friendly, Alert, Confident, Loving, Courageous, Strong'}],
#  'Bullmastiff': [{'weight': {'imperial': '100 - 130', 'metric': '45 - 59'},
#    'height': {'imperial': '24 - 27', 'metric': '61 - 69'},
#    'id': 64,
#    'name': 'Bullmastiff',
#    'bred_for': 'Estate guardian',
#    'breed_group': 'Working',
#    'life_span': '8 - 12 years',
#    'temperament': 'Docile, Reliable, Devoted, Alert, Loyal, Reserved, Loving, Protective, Powerful, Calm, Courageous'}],
#  'Cairn': [{'weight': {'imperial': '13 - 14', 'metric': '6 - 6'},
#    'height': {'imperial': '9 - 10', 'metric': '23 - 25'},
#    'id': 65,
#    'name': 'Cairn Terrier',
#    'bred_for': 'Bolting of otter, foxes, other vermin',
#    'breed_group': 'Terrier',
#    'life_span': '14 - 15 years',
#    'temperament': 'Hardy, Fearless, Assertive, Gay, Intelligent, Active'}],
#  'Cairn Terrier': [{'weight': {'imperial': '13 - 14', 'metric': '6 - 6'},
#    'height': {'imperial': '9 - 10', 'metric': '23 - 25'},
#    'id': 65,
#    'name': 'Cairn Terrier',
#    'bred_for': 'Bolting of otter, foxes, other vermin',
#    'breed_group': 'Terrier',
#    'life_span': '14 - 15 years',
#    'temperament': 'Hardy, Fearless, Assertive, Gay, Intelligent, Active'}],
#  'Canaan': [{'weight': {'imperial': '35 - 55', 'metric': '16 - 25'},
#    'height': {'imperial': '19 - 24', 'metric': '48 - 61'},
#    'id': 66,
#    'name': 'Canaan Dog',
#    'bred_for': 'Guarding flocks and encampments',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Cautious, Devoted, Alert, Quick, Intelligent, Vigilant'}],
#  'Canaan Dog': [{'weight': {'imperial': '35 - 55', 'metric': '16 - 25'},
#    'height': {'imperial': '19 - 24', 'metric': '48 - 61'},
#    'id': 66,
#    'name': 'Canaan Dog',
#    'bred_for': 'Guarding flocks and encampments',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Cautious, Devoted, Alert, Quick, Intelligent, Vigilant'}],
#  'Cane': [{'weight': {'imperial': '88 - 120', 'metric': '40 - 54'},
#    'height': {'imperial': '23.5 - 27.5', 'metric': '60 - 70'},
#    'id': 67,
#    'name': 'Cane Corso',
#    'bred_for': 'Companion, guard dog, and hunter',
#    'breed_group': 'Working',
#    'life_span': '10 - 11 years',
#    'temperament': 'Trainable, Reserved, Stable, Quiet, Even Tempered, Calm'}],
#  'Cane Corso': [{'weight': {'imperial': '88 - 120', 'metric': '40 - 54'},
#    'height': {'imperial': '23.5 - 27.5', 'metric': '60 - 70'},
#    'id': 67,
#    'name': 'Cane Corso',
#    'bred_for': 'Companion, guard dog, and hunter',
#    'breed_group': 'Working',
#    'life_span': '10 - 11 years',
#    'temperament': 'Trainable, Reserved, Stable, Quiet, Even Tempered, Calm'}],
#  'Cardigan Welsh': [{'weight': {'imperial': '25 - 38', 'metric': '11 - 17'},
#    'height': {'imperial': '10.5 - 12.5', 'metric': '27 - 32'},
#    'id': 68,
#    'name': 'Cardigan Welsh Corgi',
#    'bred_for': 'Cattle droving',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Affectionate, Devoted, Alert, Companionable, Intelligent, Active'}],
#  'Cardigan Welsh Corgi': [{'weight': {'imperial': '25 - 38',
#     'metric': '11 - 17'},
#    'height': {'imperial': '10.5 - 12.5', 'metric': '27 - 32'},
#    'id': 68,
#    'name': 'Cardigan Welsh Corgi',
#    'bred_for': 'Cattle droving',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Affectionate, Devoted, Alert, Companionable, Intelligent, Active'}],
#  'Carolina': [],
#  'Carolina Dog': [],
#  'Catahoula': [{'weight': {'imperial': '50 - 95', 'metric': '23 - 43'},
#    'height': {'imperial': '20 - 26', 'metric': '51 - 66'},
#    'id': 69,
#    'name': 'Catahoula Leopard Dog',
#    'bred_for': 'Driving livestock',
#    'breed_group': 'Herding',
#    'life_span': '10 - 12 years',
#    'temperament': 'Energetic, Inquisitive, Independent, Gentle, Intelligent, Loving'}],
#  'Cavalier': [{'weight': {'imperial': '13 - 18', 'metric': '6 - 8'},
#    'height': {'imperial': '12 - 13', 'metric': '30 - 33'},
#    'id': 71,
#    'name': 'Cavalier King Charles Spaniel',
#    'bred_for': 'Flushing small birds, companion',
#    'breed_group': 'Toy',
#    'life_span': '10 - 14 years',
#    'temperament': 'Fearless, Affectionate, Sociable, Patient, Playful, Adaptable'}],
#  'Cavalier Span': [],
#  'Chesa Bay': [],
#  'Chesa Bay Retr': [],
#  'Chihuahua': [{'weight': {'imperial': '6', 'metric': '3'},
#    'height': {'imperial': '5', 'metric': '13'},
#    'id': 77,
#    'name': 'Chihuahua',
#    'bred_for': 'Companionship',
#    'breed_group': 'Toy',
#    'life_span': '12 - 20 years',
#    'temperament': 'Devoted, Lively, Alert, Quick, Courageous'}],
#  'Chihuahua Longhair': [],
#  'Chihuahua Shorthair': [],
#  'Chinese': [{'weight': {'imperial': '10 - 13', 'metric': '5 - 6'},
#    'height': {'imperial': '11 - 13', 'metric': '28 - 33'},
#    'id': 78,
#    'name': 'Chinese Crested',
#    'bred_for': 'Ratting, lapdog, curio',
#    'breed_group': 'Toy',
#    'life_span': '10 - 14 years',
#    'temperament': 'Affectionate, Sweet-Tempered, Lively, Alert, Playful, Happy'},
#   {'weight': {'imperial': '45 - 60', 'metric': '20 - 27'},
#    'height': {'imperial': '18 - 20', 'metric': '46 - 51'},
#    'id': 79,
#    'name': 'Chinese Shar-Pei',
#    'bred_for': 'Fighting',
#    'breed_group': 'Non-Sporting',
#    'life_span': '10 years',
#    'temperament': 'Suspicious, Affectionate, Devoted, Reserved, Independent, Loving'}],
#  'Chinese Crested': [{'weight': {'imperial': '10 - 13', 'metric': '5 - 6'},
#    'height': {'imperial': '11 - 13', 'metric': '28 - 33'},
#    'id': 78,
#    'name': 'Chinese Crested',
#    'bred_for': 'Ratting, lapdog, curio',
#    'breed_group': 'Toy',
#    'life_span': '10 - 14 years',
#    'temperament': 'Affectionate, Sweet-Tempered, Lively, Alert, Playful, Happy'}],
#  'Chinese Sharpei': [],
#  'Chow': [{'weight': {'imperial': '40 - 70', 'metric': '18 - 32'},
#    'height': {'imperial': '17 - 20', 'metric': '43 - 51'},
#    'id': 81,
#    'name': 'Chow Chow',
#    'bred_for': 'Guardian, cart pulling, hunting',
#    'breed_group': 'Non-Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Aloof, Loyal, Independent, Quiet'}],
#  'Chow Chow': [{'weight': {'imperial': '40 - 70', 'metric': '18 - 32'},
#    'height': {'imperial': '17 - 20', 'metric': '43 - 51'},
#    'id': 81,
#    'name': 'Chow Chow',
#    'bred_for': 'Guardian, cart pulling, hunting',
#    'breed_group': 'Non-Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Aloof, Loyal, Independent, Quiet'}],
#  'Cirneco': [{'weight': {'imperial': '18 - 27', 'metric': '8 - 12'},
#    'height': {'imperial': '16.5 - 19.5', 'metric': '42 - 50'},
#    'id': 83,
#    'name': "Cirneco dell'Etna",
#    'bred_for': 'Hunting rabbits',
#    'breed_group': 'Hound',
#    'life_span': '12 - 14 years',
#    'temperament': 'Affectionate, Gentle'}],
#  'Cocker': [{'weight': {'imperial': '20 - 30', 'metric': '9 - 14'},
#    'height': {'imperial': '14 - 15', 'metric': '36 - 38'},
#    'id': 86,
#    'name': 'Cocker Spaniel',
#    'bred_for': 'Bird flushing, retrieving',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Trainable, Friendly, Affectionate, Playful, Quiet, Faithful'},
#   {'weight': {'imperial': '20 - 30', 'metric': '9 - 14'},
#    'height': {'imperial': '14 - 15', 'metric': '36 - 38'},
#    'id': 87,
#    'name': 'Cocker Spaniel (American)',
#    'bred_for': 'Hunting the American woodcock',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Outgoing, Sociable, Trusting, Joyful, Even Tempered, Merry'},
#   {'weight': {'imperial': '26 - 34', 'metric': '12 - 15'},
#    'height': {'imperial': '15 - 17', 'metric': '38 - 43'},
#    'id': 99,
#    'name': 'English Cocker Spaniel',
#    'bred_for': 'Bird flushing, retrieving',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 14 years',
#    'temperament': 'Trainable, Friendly, Affectionate, Playful, Quiet, Faithful'}],
#  'Cocker Spaniel': [{'weight': {'imperial': '20 - 30', 'metric': '9 - 14'},
#    'height': {'imperial': '14 - 15', 'metric': '36 - 38'},
#    'id': 86,
#    'name': 'Cocker Spaniel',
#    'bred_for': 'Bird flushing, retrieving',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Trainable, Friendly, Affectionate, Playful, Quiet, Faithful'},
#   {'weight': {'imperial': '20 - 30', 'metric': '9 - 14'},
#    'height': {'imperial': '14 - 15', 'metric': '36 - 38'},
#    'id': 87,
#    'name': 'Cocker Spaniel (American)',
#    'bred_for': 'Hunting the American woodcock',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Outgoing, Sociable, Trusting, Joyful, Even Tempered, Merry'},
#   {'weight': {'imperial': '26 - 34', 'metric': '12 - 15'},
#    'height': {'imperial': '15 - 17', 'metric': '38 - 43'},
#    'id': 99,
#    'name': 'English Cocker Spaniel',
#    'bred_for': 'Bird flushing, retrieving',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 14 years',
#    'temperament': 'Trainable, Friendly, Affectionate, Playful, Quiet, Faithful'}],
#  'Collie': [{'weight': {'imperial': '45 - 55', 'metric': '20 - 25'},
#    'height': {'imperial': '20 - 22', 'metric': '51 - 56'},
#    'id': 32,
#    'name': 'Bearded Collie',
#    'bred_for': 'Sheep herding',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Self-confidence, Hardy, Lively, Alert, Intelligent, Active'},
#   {'weight': {'imperial': '30 - 45', 'metric': '14 - 20'},
#    'height': {'imperial': '18 - 22', 'metric': '46 - 56'},
#    'id': 50,
#    'name': 'Border Collie',
#    'bred_for': 'Sheep herder',
#    'breed_group': 'Herding',
#    'life_span': '12 - 16 years',
#    'temperament': 'Tenacious, Keen, Energetic, Responsive, Alert, Intelligent'},
#   {'weight': {'imperial': '50 - 70', 'metric': '23 - 32'},
#    'height': {'imperial': '22 - 26', 'metric': '56 - 66'},
#    'id': 88,
#    'name': 'Collie',
#    'bred_for': 'Sheep herding',
#    'breed_group': 'Herding',
#    'life_span': '10 - 14 years',
#    'temperament': 'Friendly, Loyal, Gentle, Intelligent, Active, Protective'}],
#  'Collie Rough': [],
# ...
#    'breed_group': 'Toy',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Responsive, Inquisitive, Alert, Quick, Joyful'}],
#  'Silky Terrier': [{'weight': {'imperial': '8 - 10', 'metric': '4 - 5'},
#    'height': {'imperial': '9 - 10', 'metric': '23 - 25'},
#    'id': 228,
#    'name': 'Silky Terrier',
#    'bred_for': 'Small vermin hunting, companionship',
#    'breed_group': 'Toy',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Responsive, Inquisitive, Alert, Quick, Joyful'}],
#  'Skye': [{'weight': {'imperial': '35 - 45', 'metric': '16 - 20'},
#    'height': {'imperial': '9 - 10', 'metric': '23 - 25'},
#    'id': 229,
#    'name': 'Skye Terrier',
#    'bred_for': 'Vermin hunting',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 14 years',
#    'temperament': 'Fearless, Friendly, Loyal, Gay, Intelligent, Good-tempered'}],
#  'Skye Terrier': [{'weight': {'imperial': '35 - 45', 'metric': '16 - 20'},
#    'height': {'imperial': '9 - 10', 'metric': '23 - 25'},
#    'id': 229,
#    'name': 'Skye Terrier',
#    'bred_for': 'Vermin hunting',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 14 years',
#    'temperament': 'Fearless, Friendly, Loyal, Gay, Intelligent, Good-tempered'}],
#  'Smooth Fox': [{'weight': {'imperial': 'up - 18', 'metric': 'NaN - 8'},
#    'height': {'imperial': '15.5', 'metric': '39'},
#    'id': 232,
#    'name': 'Smooth Fox Terrier',
#    'bred_for': 'Fox bolting',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 14 years',
#    'temperament': 'Fearless, Affectionate, Alert, Playful, Intelligent, Active'}],
#  'Smooth Fox Terrier': [{'weight': {'imperial': 'up - 18',
#     'metric': 'NaN - 8'},
#    'height': {'imperial': '15.5', 'metric': '39'},
#    'id': 232,
#    'name': 'Smooth Fox Terrier',
#    'bred_for': 'Fox bolting',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 14 years',
#    'temperament': 'Fearless, Affectionate, Alert, Playful, Intelligent, Active'}],
#  'Soft Coated Wheaten': [{'weight': {'imperial': '30 - 40',
#     'metric': '14 - 18'},
#    'height': {'imperial': '16 - 18', 'metric': '41 - 46'},
#    'id': 233,
#    'name': 'Soft Coated Wheaten Terrier',
#    'bred_for': 'Vermin hunting, guarding, all-around farm helper',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 15 years',
#    'temperament': 'Affectionate, Spirited, Energetic, Playful, Intelligent, Faithful'}],
#  'Soft Coated Wheaten Terrier': [{'weight': {'imperial': '30 - 40',
#     'metric': '14 - 18'},
#    'height': {'imperial': '16 - 18', 'metric': '41 - 46'},
#    'id': 233,
#    'name': 'Soft Coated Wheaten Terrier',
#    'bred_for': 'Vermin hunting, guarding, all-around farm helper',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 15 years',
#    'temperament': 'Affectionate, Spirited, Energetic, Playful, Intelligent, Faithful'}],
#  'Spanish Water Dog': [{'weight': {'imperial': '30 - 50', 'metric': '14 - 23'},
#    'height': {'imperial': '16 - 20', 'metric': '41 - 51'},
#    'id': 235,
#    'name': 'Spanish Water Dog',
#    'bred_for': 'Herding flocks of sheep and goats from one pasture to another',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Trainable, Diligent, Affectionate, Loyal, Athletic, Intelligent'}],
#  'St. Bernard Rough': [],
#  'St. Bernard Rough Coat': [],
#  'St. Bernard Smooth': [],
#  'St. Bernard Smooth Coat': [],
#  'Staffordshire': [{'weight': {'imperial': '50 - 60', 'metric': '23 - 27'},
#    'height': {'imperial': '17 - 19', 'metric': '43 - 48'},
#    'id': 16,
#    'name': 'American Staffordshire Terrier',
#    'country_code': 'US',
#    'bred_for': '',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 15 years',
#    'temperament': 'Tenacious, Friendly, Devoted, Loyal, Attentive, Courageous'},
#   {'weight': {'imperial': '24 - 38', 'metric': '11 - 17'},
#    'height': {'imperial': '14 - 16', 'metric': '36 - 41'},
#    'id': 238,
#    'name': 'Staffordshire Bull Terrier',
#    'bred_for': '',
#    'breed_group': 'Terrier',
#    'life_span': '12 - 14 years',
#    'temperament': 'Reliable, Fearless, Bold, Affectionate, Loyal, Intelligent, Courageous'}],
#  'Standard': [{'weight': {'imperial': '30 - 50', 'metric': '14 - 23'},
#    'height': {'imperial': '17.5 - 19.5', 'metric': '44 - 50'},
#    'id': 239,
#    'name': 'Standard Schnauzer',
#    'bred_for': 'Ratting, guarding',
#    'breed_group': 'Working',
#    'life_span': '13 - 15 years',
#    'temperament': 'Trainable, Good-natured, Devoted, Lively, Playful, Intelligent'}],
#  'Standard Poodle': [],
#  'Standard Schnauzer': [{'weight': {'imperial': '30 - 50',
#     'metric': '14 - 23'},
#    'height': {'imperial': '17.5 - 19.5', 'metric': '44 - 50'},
#    'id': 239,
#    'name': 'Standard Schnauzer',
#    'bred_for': 'Ratting, guarding',
#    'breed_group': 'Working',
#    'life_span': '13 - 15 years',
#    'temperament': 'Trainable, Good-natured, Devoted, Lively, Playful, Intelligent'}],
#  'Swedish': [{'weight': {'imperial': '33 - 53', 'metric': '15 - 24'},
#    'height': {'imperial': '16 - 20', 'metric': '41 - 51'},
#    'id': 241,
#    'name': 'Swedish Lapphund',
#    'breed_group': 'Herding',
#    'life_span': '10 - 13 years',
#    'temperament': 'Kind, Affectionate, Lively, Alert, Trainable, Versatile'},
#   {'weight': {'imperial': '20 - 30', 'metric': '9 - 14'},
#    'height': {'imperial': '11.5 - 13.5', 'metric': '29 - 34'},
#    'id': 242,
#    'name': 'Swedish Vallhund',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Fearless, Friendly, Energetic, Alert, Intelligent, Watchful'}],
#  'Swedish Vallhund': [{'weight': {'imperial': '20 - 30', 'metric': '9 - 14'},
#    'height': {'imperial': '11.5 - 13.5', 'metric': '29 - 34'},
#    'id': 242,
#    'name': 'Swedish Vallhund',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Fearless, Friendly, Energetic, Alert, Intelligent, Watchful'}],
#  'Tan Hound': [],
#  'Tan Hound Mix': [],
#  'Tibetan': [{'weight': {'imperial': '85 - 140', 'metric': '39 - 64'},
#    'height': {'imperial': '24 - 26', 'metric': '61 - 66'},
#    'id': 244,
#    'name': 'Tibetan Mastiff',
#    'breed_group': 'Working',
#    'life_span': '10 - 14 years',
#    'temperament': 'Strong Willed, Tenacious, Aloof, Stubborn, Intelligent, Protective'},
#   {'weight': {'imperial': '9 - 15', 'metric': '4 - 7'},
#    'height': {'imperial': '10', 'metric': '25'},
#    'id': 245,
#    'name': 'Tibetan Spaniel',
#    'breed_group': 'Non-Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Willful, Aloof, Assertive, Independent, Playful, Intelligent, Happy'},
#   {'weight': {'imperial': '20 - 24', 'metric': '9 - 11'},
#    'height': {'imperial': '14 - 17', 'metric': '36 - 43'},
#    'id': 246,
#    'name': 'Tibetan Terrier',
#    'bred_for': 'Good luck charms, mascots, watchdogs, herding dogs, and companions',
#    'breed_group': 'Non-Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Affectionate, Energetic, Amiable, Reserved, Gentle, Sensitive'}],
#  'Tibetan Spaniel': [{'weight': {'imperial': '9 - 15', 'metric': '4 - 7'},
#    'height': {'imperial': '10', 'metric': '25'},
#    'id': 245,
#    'name': 'Tibetan Spaniel',
#    'breed_group': 'Non-Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Willful, Aloof, Assertive, Independent, Playful, Intelligent, Happy'}],
#  'Tibetan Terrier': [{'weight': {'imperial': '20 - 24', 'metric': '9 - 11'},
#    'height': {'imperial': '14 - 17', 'metric': '36 - 43'},
#    'id': 246,
#    'name': 'Tibetan Terrier',
#    'bred_for': 'Good luck charms, mascots, watchdogs, herding dogs, and companions',
#    'breed_group': 'Non-Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Affectionate, Energetic, Amiable, Reserved, Gentle, Sensitive'}],
#  'Toy': [{'weight': {'imperial': '8 - 14', 'metric': '4 - 6'},
#    'height': {'imperial': '10', 'metric': '25'},
#    'id': 104,
#    'name': 'English Toy Spaniel',
#    'bred_for': 'Companion of kings',
#    'breed_group': 'Toy',
#    'life_span': '10 - 12 years',
#    'temperament': 'Affectionate, Reserved, Playful, Gentle, Happy, Loving'},
#   {'weight': {'imperial': '6 - 8', 'metric': '3 - 4'},
#    'height': {'imperial': '10 - 12', 'metric': '25 - 30'},
#    'id': 105,
#    'name': 'English Toy Terrier',
#    'bred_for': 'Rat-baiting',
#    'life_span': '12 - 13 years',
#    'temperament': 'Stubborn, Alert, Companionable, Intelligent, Cunning, Trainable'},
#   {'weight': {'imperial': '6 - 9', 'metric': '3 - 4'},
#    'height': {'imperial': '9 - 11', 'metric': '23 - 28'},
#    'id': 197,
#    'name': 'Poodle (Toy)',
#    'life_span': '18 years'},
#   {'weight': {'imperial': '3 - 6', 'metric': '1 - 3'},
#    'height': {'imperial': '7.5 - 10.5', 'metric': '19 - 27'},
#    'id': 211,
#    'name': 'Russian Toy',
#    'breed_group': 'Toy',
#    'life_span': '10 - 12 years'},
#   {'weight': {'imperial': '4 - 9', 'metric': '2 - 4'},
#    'height': {'imperial': '8 - 11', 'metric': '20 - 28'},
#    'id': 248,
#    'name': 'Toy Fox Terrier',
#    'breed_group': 'Toy',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Spirited, Alert, Loyal, Playful, Intelligent'},
#   {'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
#    'height': {'imperial': '10', 'metric': '25'},
#    'id': 249,
#    'name': 'Toy Poodle',
#    'breed_group': 'Toy',
#    'life_span': '14 - 18 years'}],
#  'Toy Fox': [{'weight': {'imperial': '4 - 9', 'metric': '2 - 4'},
#    'height': {'imperial': '8 - 11', 'metric': '20 - 28'},
#    'id': 248,
#    'name': 'Toy Fox Terrier',
#    'breed_group': 'Toy',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Spirited, Alert, Loyal, Playful, Intelligent'}],
#  'Toy Fox Terrier': [{'weight': {'imperial': '4 - 9', 'metric': '2 - 4'},
#    'height': {'imperial': '8 - 11', 'metric': '20 - 28'},
#    'id': 248,
#    'name': 'Toy Fox Terrier',
#    'breed_group': 'Toy',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Spirited, Alert, Loyal, Playful, Intelligent'}],
#  'Toy Poodle': [{'weight': {'imperial': '5 - 10', 'metric': '2 - 5'},
#    'height': {'imperial': '10', 'metric': '25'},
#    'id': 249,
#    'name': 'Toy Poodle',
#    'breed_group': 'Toy',
#    'life_span': '14 - 18 years'}],
#  'Treeing Cur': [],
#  'Treeing Tennesse Brindle': [],
#  'Treeing Walker': [{'weight': {'imperial': '45 - 80', 'metric': '20 - 36'},
#    'height': {'imperial': '20 - 27', 'metric': '51 - 69'},
#    'id': 250,
#    'name': 'Treeing Walker Coonhound',
#    'breed_group': 'Hound',
#    'life_span': '10 - 13 years',
#    'temperament': 'Clever, Affectionate, Confident, Intelligent, Loving, Trainable'}],
#  'Treeing Walker Coonhound': [{'weight': {'imperial': '45 - 80',
#     'metric': '20 - 36'},
#    'height': {'imperial': '20 - 27', 'metric': '51 - 69'},
#    'id': 250,
#    'name': 'Treeing Walker Coonhound',
#    'breed_group': 'Hound',
#    'life_span': '10 - 13 years',
#    'temperament': 'Clever, Affectionate, Confident, Intelligent, Loving, Trainable'}],
#  'Vizsla': [{'weight': {'imperial': '50 - 65', 'metric': '23 - 29'},
#    'height': {'imperial': '21 - 24', 'metric': '53 - 61'},
#    'id': 251,
#    'name': 'Vizsla',
#    'bred_for': 'Pointing and trailing',
#    'breed_group': 'Sporting',
#    'life_span': '10 - 14 years',
#    'temperament': 'Affectionate, Energetic, Loyal, Gentle, Quiet'},
#   {'weight': {'imperial': '45 - 65', 'metric': '20 - 29'},
#    'height': {'imperial': '21.5 - 25', 'metric': '55 - 64'},
#    'id': 261,
#    'name': 'Wirehaired Vizsla',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 14 years'}],
#  'Weimaraner': [{'weight': {'imperial': '55 - 90', 'metric': '25 - 41'},
#    'height': {'imperial': '23 - 27', 'metric': '58 - 69'},
#    'id': 253,
#    'name': 'Weimaraner',
#    'bred_for': 'Large game trailing and versatile gundog',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Steady, Aloof, Stubborn, Energetic, Alert, Intelligent, Powerful, Fast'}],
#  'Welsh': [{'weight': {'imperial': '25 - 38', 'metric': '11 - 17'},
#    'height': {'imperial': '10.5 - 12.5', 'metric': '27 - 32'},
#    'id': 68,
#    'name': 'Cardigan Welsh Corgi',
#    'bred_for': 'Cattle droving',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Affectionate, Devoted, Alert, Companionable, Intelligent, Active'},
#   {'weight': {'imperial': '25 - 30', 'metric': '11 - 14'},
#    'height': {'imperial': '10 - 12', 'metric': '25 - 30'},
#    'id': 184,
#    'name': 'Pembroke Welsh Corgi',
#    'bred_for': 'Driving stock to market in northern Wales',
#    'breed_group': 'Herding',
#    'life_span': '12 - 14 years',
#    'temperament': 'Tenacious, Outgoing, Friendly, Bold, Playful, Protective'},
#   {'weight': {'imperial': '35 - 55', 'metric': '16 - 25'},
#    'height': {'imperial': '17 - 19', 'metric': '43 - 48'},
#    'id': 254,
#    'name': 'Welsh Springer Spaniel',
#    'bred_for': 'Flushing and retrieving birds',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Stubborn, Friendly, Affectionate, Loyal, Playful, Active'},
#   {'weight': {'imperial': '20 - 22', 'metric': '9 - 10'},
#    'height': {'imperial': '15 - 15.5', 'metric': '38 - 39'},
#    'id': 255,
#    'name': 'Welsh Terrier',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 14 years',
#    'temperament': 'Friendly, Spirited, Alert, Intelligent'}],
#  'Welsh Springer Spaniel': [{'weight': {'imperial': '35 - 55',
#     'metric': '16 - 25'},
#    'height': {'imperial': '17 - 19', 'metric': '43 - 48'},
#    'id': 254,
#    'name': 'Welsh Springer Spaniel',
#    'bred_for': 'Flushing and retrieving birds',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 15 years',
#    'temperament': 'Stubborn, Friendly, Affectionate, Loyal, Playful, Active'}],
#  'Welsh Terrier': [{'weight': {'imperial': '20 - 22', 'metric': '9 - 10'},
#    'height': {'imperial': '15 - 15.5', 'metric': '38 - 39'},
#    'id': 255,
#    'name': 'Welsh Terrier',
#    'breed_group': 'Terrier',
#    'life_span': '10 - 14 years',
#    'temperament': 'Friendly, Spirited, Alert, Intelligent'}],
#  'West': [{'weight': {'imperial': '15 - 22', 'metric': '7 - 10'},
#    'height': {'imperial': '10 - 11', 'metric': '25 - 28'},
#    'id': 256,
#    'name': 'West Highland White Terrier',
#    'bred_for': 'Fox, badger, vermin hunting',
#    'breed_group': 'Terrier',
#    'life_span': '15 - 20 years',
#    'temperament': 'Hardy, Friendly, Alert, Independent, Gay, Active, Courageous'}],
#  'West Highland': [{'weight': {'imperial': '15 - 22', 'metric': '7 - 10'},
#    'height': {'imperial': '10 - 11', 'metric': '25 - 28'},
#    'id': 256,
#    'name': 'West Highland White Terrier',
#    'bred_for': 'Fox, badger, vermin hunting',
#    'breed_group': 'Terrier',
#    'life_span': '15 - 20 years',
#    'temperament': 'Hardy, Friendly, Alert, Independent, Gay, Active, Courageous'}],
#  'Whippet': [{'weight': {'imperial': '25 - 35', 'metric': '11 - 16'},
#    'height': {'imperial': '18 - 22', 'metric': '46 - 56'},
#    'id': 257,
#    'name': 'Whippet',
#    'bred_for': 'Coursing, racing',
#    'breed_group': 'Hound',
#    'life_span': '12 - 15 years',
#    'temperament': 'Friendly, Affectionate, Lively, Gentle, Intelligent, Quiet'}],
#  'Wire Hair Fox': [],
#  'Wire Hair Fox Terrier': [],
#  'Wirehaired Pointing Griffon': [{'weight': {'imperial': '45 - 70',
#     'metric': '20 - 32'},
#    'height': {'imperial': '20 - 24', 'metric': '51 - 61'},
#    'id': 260,
#    'name': 'Wirehaired Pointing Griffon',
#    'bred_for': 'Gundog, "swamp-tromping", Flushing, pointing, and retrieving water fowl & game birds',
#    'breed_group': 'Sporting',
#    'life_span': '12 - 14 years',
#    'temperament': 'Loyal, Gentle, Vigilant, Trainable, Proud'}],
#  'Yorkshire': [{'weight': {'imperial': '4 - 7', 'metric': '2 - 3'},
#    'height': {'imperial': '8 - 9', 'metric': '20 - 23'},
#    'id': 264,
#    'name': 'Yorkshire Terrier',
#    'bred_for': 'Small vermin hunting',
#    'breed_group': 'Toy',
#    'life_span': '12 - 16 years',
#    'temperament': 'Bold, Independent, Confident, Intelligent, Courageous'}],
#  'Yorkshire Terrier': [{'weight': {'imperial': '4 - 7', 'metric': '2 - 3'},
#    'height': {'imperial': '8 - 9', 'metric': '20 - 23'},
#    'id': 264,
#    'name': 'Yorkshire Terrier',
#    'bred_for': 'Small vermin hunting',
#    'breed_group': 'Toy',
#    'life_span': '12 - 16 years',
#    'temperament': 'Bold, Independent, Confident, Intelligent, Courageous'}]}

# %%
moreinfo_breed

# %%
morescrape_dict={}
for breed in moreinfo_breed:
    time.sleep(1)
    info_dict={}
    query= '+'.join(breed.split(' ')) + '+breed'
    search_page = requests.get('https://www.akc.org/?s='+query)
    search_soup = BeautifulSoup(search_page.content, 'html.parser')
    breed_link = search_soup.find('a', class_="d-iblock f-11 lh-solid").attrs['href']

    info_page = requests.get(breed_link)
    info_soup= BeautifulSoup(info_page.content, 'html.parser')
    info = info_soup.findAll('span', class_="attribute-list__description")
    info_list = [tag.text for tag in info]
    for piece in info_list:
        if 'inches' in piece:
            info_dict['height'] = piece
        if 'pounds' in piece:
            info_dict['weight'] = piece
        if 'years' in piece:
            info_dict['life_span'] = piece
    morescrape_dict[breed] = info_dict

# %%
morescrape_dict['American']=morescrape_dict['American Eskimo']
morescrape_dict['Great']=morescrape_dict['Mastiff']
morescrape_dict['Irish']=morescrape_dict['English']
morescrape_dict['Toy']=noinfo_dict['Chihuahua Longhair']

# %%
clean_breed_dict={}
for breed in breed_dict.keys():
    try:
        if breed in noinfo_dict.keys():
            clean_breed_dict[breed]= noinfo_dict[breed]
        elif breed in morescrape_dict.keys():
            clean_breed_dict[breed]= morescrape_dict[breed]
        else:
            attr_dict = {}
            attr_dict['weight'] = breed_dict[breed][0]['weight']['imperial']
            attr_dict['height'] = breed_dict[breed][0]['height']['imperial']
            attr_dict['life_span'] = breed_dict[breed][0]['life_span']
            clean_breed_dict[breed] = attr_dict
    except TypeError:
        attr_dict = {}
        attr_dict['weight'] = breed_dict[breed][0]['weight']
        attr_dict['height'] = breed_dict[breed][0]['height']
        attr_dict['life_span'] = breed_dict[breed][0]['life_span']
        clean_breed_dict[breed]=attr_dict

# %%
len(clean_breed_dict)
# Out:
# 278

# %%
import re

# %%
breed_df = pd.DataFrame.from_dict(clean_breed_dict, orient='index')

# %%
breed_df['clean_weight'] = breed_df.weight.apply(lambda x: max([float(item) for item in (re.findall('\d+', x))]) if isinstance(x, str) else x)

# %%
breed_df['clean_height'] = breed_df.height.apply(lambda x: max([float(item) for item in (re.findall('\d+', x))]) if isinstance(x, str) else x)

# %%
breed_df['clean_life'] = breed_df.life_span.apply(lambda x: max([float(item) for item in (re.findall('\d+', x))]) if isinstance(x, str) else x)

# %%
attr_df= breed_df[['clean_weight', 'clean_height', 'clean_life']]

# %%
attr_df.to_csv('breed_info.csv')

# %%
attr_df.head()
# Out:
#                   clean_weight  clean_height  clean_life
# Affenpinscher             13.0          11.0        12.0
# Afghan                    60.0          27.0        13.0
# Airedale                  65.0          23.0        13.0
# Airedale Terrier          65.0          23.0        13.0
# Akbash                   120.0          34.0        12.0

# %%
 df= df[df.is_dog==1].reset_index()

# %% [markdown]
# Combining the two dataframes and creating a final dataframe

# %%
df.breed1 = np.where(df.breed1=='Black', 'Black Tan Coonhound', df.breed1)

#cases = [df.breed2 = df.breed1.split()[-1], None]
df.breed2 = np.where((df.breed2 == 'Tan Hound Mix')|(df.breed2 == 'Tan Hound'), None, df.breed2)

# %%
df.breed2 = df.breed2.apply(lambda x: None if type(x)==float else x)

# %%
df.is_breed2 = df.breed2.apply(lambda x: int(x!=None))

# %%
max_weights=[]
bad_breeds=[]
for animal in df.index:
    try:
        if df.loc[animal, 'is_breed2']!=0:
            max_weights.append((attr_df.loc[df.loc[animal, 'breed1'].rstrip('Mix'), 'clean_weight'] + attr_df.loc[df.loc[animal, 'breed2'].rstrip('Mix'), 'clean_weight'])/2)
        else:
            max_weights.append(attr_df.loc[df.loc[animal, 'breed1'].rstrip('Mix').strip(), 'clean_weight'])
    except KeyError as p:
        breed=str(p).strip("'")
        if breed== 'Chinese Sharpe' or breed=='Saluk':
            max_weights.append(60)
        elif breed== 'Hound' or breed == 'Afghan Hound':
            max_weights.append(75)
        elif breed=='Patterdale Terr':
            max_weights.append(20)
        elif breed=='Borzo':
            max_weights.append(100)
        elif breed=='Basenj':
            max_weights.append(26)
        else:
            max_weights.append(30)

# %%
df['max_weight'] = max_weights

# %%
invest = [(df.loc[animal, 'breed1'], df.loc[animal, 'breed2'])for animal in bad_breeds]

# %%
#code for max height column

max_heights=[]
bad_breeds=[]

for animal in df.index:

    try:

        if df.loc[animal, 'is_breed2']!=0:

            max_heights.append((attr_df.loc[df.loc[animal, 'breed1'].rstrip('Mix'), 'clean_height'] + attr_df.loc[df.loc[animal, 'breed2'].rstrip('Mix'), 'clean_height'])/2)

        else:

            max_heights.append(attr_df.loc[df.loc[animal, 'breed1'].rstrip('Mix').strip(), 'clean_height'])

    except KeyError as p:
        breed=str(p).strip("'")
        if breed== 'Chinese Sharpe':
            max_heights.append(20)
        elif breed== 'Hound' or breed == 'Saluk':
            max_heights.append(27)
        elif breed == 'Afghan Hound':
            max_heights.append(30)
        elif breed=='Patterdale Terr':
            max_heights.append(15)
        elif breed=='Borzo':
            max_heights.append(36)
        elif breed=='Basenj':
            max_heights.append(17)
        elif breed=='Pembroke Welsh Corg' or breed=='Cardigan Welsh Corg':
            max_heights.append(13)
        else:    
            print(breed)

# %%
df['max_height']=max_heights

# %%
max_life=[]


for animal in df.index:

    try:

        if df.loc[animal, 'is_breed2']!=0:

            max_life.append((attr_df.loc[df.loc[animal, 'breed1'].rstrip('Mix'), 'clean_life'] + attr_df.loc[df.loc[animal, 'breed2'].rstrip('Mix'), 'clean_life'])/2)

        else:

            max_life.append(attr_df.loc[df.loc[animal, 'breed1'].rstrip('Mix').strip(), 'clean_life'])

    except KeyError as p:
        breed=str(p).strip("'")
        if breed== 'Chinese Sharpe':
            max_life.append(11)
        elif breed== 'Hound' or breed=='Patterdale Terr':
            max_life.append(12)
        elif breed == 'Saluk' or breed == 'Afghan Hound':
            max_life.append(14)
        elif breed=='Borzo':
            max_life.append(10)
        elif breed=='Basenj':
            max_life.append(16)
        elif breed=='Pembroke Welsh Corg' or breed=='Cardigan Welsh Corg':
            max_life.append(15)
        else:    
            print(breed)

# %%
df['max_life']=max_life

# %%
df.to_csv('shelter_breed.csv')
